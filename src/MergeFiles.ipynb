# %%
import json

# Load first file
with open("year2018.json", "r", encoding="utf-8") as f:
    data_a = json.load(f)  # data_a is a list

# Load second file
with open("year2019.json", "r", encoding="utf-8") as f:
    data_b = json.load(f)  # data_b is a list

# Load second file
with open("year2020.json", "r", encoding="utf-8") as f:
    data_c = json.load(f)  # data_b is a list

# Load second file
with open("year2021.json", "r", encoding="utf-8") as f:
    data_d = json.load(f)  # data_b is a list

# Load second file
with open("year2022.json", "r", encoding="utf-8") as f:
    data_e = json.load(f)  # data_b is a list
# Load second file
with open("year2023.json", "r", encoding="utf-8") as f:
    data_f = json.load(f)  # data_b is a list
# Merge the lists
merged_data = data_a + data_b + data_c + data_d +data_e +data_f # concatenates lists

# Save merged result to a new JSON file
with open("allYear.json", "w", encoding="utf-8") as f:
    json.dump(merged_data, f, ensure_ascii=False, indent=4)
# Out:
# Merged 2792 + 3082 items into merged.json (20216 total)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
