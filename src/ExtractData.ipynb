# %% [markdown]
# # Scopus Data Structure
#
# ## Root: abstracts-retrieval-response
#
# ### 1. item
# - **`ait:process-info`** (Processing metadata)
#   - ait:status - Processing state
#   - ait:date-delivered - Delivery timestamp
#   - ait:date-sort - Sorting date
#
# - **`bibrecord`** (Bibliographic record)
#   - **`head`** (Header information)
#     - **`author-group[]`** (Array of author-affiliation groupings)
#       - affiliation - Organization details
#       - author[] - Array of authors
#     - citation-title - Chapter title
#     - abstracts - Abstract content (null in this case)
#     - correspondence - Contact author info
#     - **`citation-info`**
#       - citation-type - Document type
#       - citation-language - Language
#     - **`source`** (Publication source)
#       - sourcetitle-abbrev - Abbreviated source title
#       - website - Publisher URL
#       - volisspag - Volume/issue/pages
#       - publicationyear
#       - isbn[] - Array of ISBNs
#       - publisher
#       - sourcetitle - Full book title
#       - publicationdate
#     - **`enhancement`**
#       - classificationgroup
#         - classifications[] - Array of subject codes
#
#   - **`item-info`** (Item metadata)
#     - copyright
#     - dbcollection[] - Database sources
#     - history - Creation date
#     - **`itemidlist`** (Identifiers)
#       - itemid[] - Array of various ID types
#       - ce:doi - Digital Object Identifier
#
#   - **`tail`**
#     - **`bibliography`** (References section)
#       - reference[] (Array of 76 references)
#         - ref-fulltext - Full citation text
#         - ref-info - Structured reference data
#
# ### 2. affiliation[] (Array)
# - Detailed affiliation objects with:
#   - @id - Affiliation ID
#   - affiliation-city
#   - affilname
#   - affiliation-country
#
# ### 3. coredata (Core metadata)
# - srctype - Source type
# - eid - Electronic ID
# - prism:coverDate - Cover date
# - prism:aggregationType - Aggregation type
# - dc:creator - Author information
# - **`link[]`** - Related URLs
#   - @rel="self" - Self link
#   - @rel="scopus" - Scopus link
#   - @rel="scopus-citedby" - Cited-by link
# - prism:isbn[] - ISBN array
# - prism:publicationName - Publication name
# - source-id - Source ID
# - citedby-count - Citation count
# - subtype - Document subtype
# - prism:pageRange - Page range
# - dc:title - Title
# - openaccess - Open access status
# - prism:doi - DOI
# - dc:identifier - Identifier
# - dc:publisher - Publisher
#
# ### 4. idxterms
# - Index terms (null in this case)
#
# ### 5. language
# - Document language
#
# ### 6. authkeywords
# - Author keywords (null in this case)
#
# ### 7. subject-areas
# - **`subject-area[]`** (Array)
#   - Discipline classifications
#
# ### 8. authors
# - **`author[]`** (Array)
#   - Author objects with affiliation links
#
# ## Key Structural Features:
#
# - **Dual Author Representations**: Authors in both grouped and flat formats
# - **Multiple Identifier Systems**: Various IDs for cross-referencing
# - **Hierarchical Affiliations**: Detailed organizational structure
# - **Comprehensive References**: 76 fully-structured citations
# - **Rich Metadata**: Extensive processing and delivery information

# %%
import json
import pandas as pd
import os
from pprint import pprint


def ensure_list(obj):
    if isinstance(obj, list):
        return obj
    elif obj is None:
        return []
    else:
        return [obj]
# Load and analyze the complete structure with proper error handling
def extract_all_to_dataframes(data):
    # Check if the expected structure exists
    if 'abstracts-retrieval-response' not in data:
        print("Error: Expected 'abstracts-retrieval-response' not found in JSON structure")
        print("Available keys:", list(data.keys()))
        return {}
    
    root = data['abstracts-retrieval-response']
    
    def safe_get(obj, keys, default=None):
        """Safely navigate nested dictionaries"""
        if not isinstance(obj, dict):
            return default
        current = obj
        for key in keys:
            if isinstance(current, dict) and key in current:
                current = current[key]
            else:
                return default
        return current

    # Initialize all DataFrames
    dataframes = {}
    
    # 1. CORE METADATA DataFrame
    coredata = root.get('coredata', {})
    
    # Extract ISBNs
    isbns = ensure_list(coredata.get('prism:isbn', []))
    isbn_electronic = ''
    isbn_print = ''
    for isbn in isbns:
        if isinstance(isbn, dict) and '$' in isbn:
            if not isbn_electronic:
                isbn_electronic = isbn['$']
            else:
                isbn_print = isbn['$']
    
    # Extract links
    links = ensure_list(coredata.get('link', []))
    link_info = []
    for link in links:
        if isinstance(link, dict):
            link_info.append(f"{link.get('@rel', '')}: {link.get('@href', '')}")
    
    core_metadata_data = {
        'title': [coredata.get('dc:title', '')],
        'description':[coredata.get('dc:description', '')] ,
        'document_type': [coredata.get('subtypeDescription', '')],
        'publication_date': [coredata.get('prism:coverDate', '')],
        'doi': [coredata.get('prism:doi', '')],
        'pages': [f"{coredata.get('prism:startingPage', '')}-{coredata.get('prism:endingPage', '')}"],
        'publication_name': [coredata.get('prism:publicationName', '')],
        'publisher': [coredata.get('dc:publisher', '')],
        'cited_by_count': [coredata.get('citedby-count', '')],
        'scopus_id': [coredata.get('dc:identifier', '')],
        'eid': [coredata.get('eid', '')],
        'open_access': [coredata.get('openaccessFlag', '')],
        'isbn_electronic': [isbn_electronic],
        'isbn_print': [isbn_print],
        'links': ['; '.join(link_info)]
    }
    dataframes['core_metadata'] = pd.DataFrame(core_metadata_data)

    # 2. AUTHORS INFORMATION DataFrame
    authors_data = []
    authors_dict = root.get('authors', {})
    authors = ensure_list(authors_dict.get('author', [])) if authors_dict else []
    
    for author in authors:
        if isinstance(author, dict):
            affils = ensure_list(author.get('affiliation', []))
            authors_data.append({
                'author_id': author.get('@auid', ''),
                'sequence': author.get('@seq', ''),
                'given_name': author.get('ce:given-name', ''),
                'surname': author.get('ce:surname', ''),
                'full_name': f"{author.get('ce:given-name', '')} {author.get('ce:surname', '')}",
                'degrees': author.get('ce:degrees', ''),
                'affiliation_count': len(affils)
            })
    dataframes['authors'] = pd.DataFrame(authors_data)

    # 3. AFFILIATIONS DataFrame
    affiliations_data = []
    affiliations = ensure_list(root.get('affiliation', []))
    for affil in affiliations:
        if isinstance(affil, dict):
            affiliations_data.append({
                'affiliation_id': affil.get('@id', ''),
                'name': affil.get('affilname', ''),
                'city': affil.get('affiliation-city', ''),
                'country': affil.get('affiliation-country', '')
            })
    dataframes['affiliations'] = pd.DataFrame(affiliations_data)

    # 4. SUBJECT AREAS DataFrame
    subject_areas_data = []
    subject_areas = ensure_list(safe_get(root, ['subject-areas', 'subject-area'], []))
    for area in subject_areas:
        if isinstance(area, dict):
            subject_areas_data.append({
                'subject_area': area.get('$', ''),
                'subject_code': area.get('@code', '')
            })
    dataframes['subject_areas'] = pd.DataFrame(subject_areas_data)

    # 5. PROCESSING INFORMATION DataFrame
    item = root.get('item', {})
    process_info = item.get('ait:process-info', {})
    status_info = process_info.get('ait:status', {})
    date_delivered = process_info.get('ait:date-delivered', {})
    
    processing_data = {
        'status': [status_info.get('@state', '')],
        'delivery_year': [date_delivered.get('@year', '')],
        'delivery_month': [date_delivered.get('@month', '')],
        'delivery_day': [date_delivered.get('@day', '')],
        'delivery_date': [f"{date_delivered.get('@year', '')}-{date_delivered.get('@month', '')}-{date_delivered.get('@day', '')}"]
    }
    dataframes['processing_info'] = pd.DataFrame(processing_data)

    # 6. BIBRECORD - Detailed bibliographic data
    bibrecord = item.get('bibrecord', {})
    head = bibrecord.get('head', {})
    
    # Author Groups DataFrame
    author_groups_data = []
    author_groups = ensure_list(head.get('author-group', []))
    for i, group in enumerate(author_groups):
        if isinstance(group, dict):
            affiliation = group.get('affiliation', {})
            organizations = ensure_list(affiliation.get('organization', []))
            org_names = [org.get('$', '') for org in organizations if isinstance(org, dict)]
            
            author_groups_data.append({
                'group_number': i + 1,
                'country': affiliation.get('@country', ''),
                'city': affiliation.get('city', ''),
                'organizations': '; '.join(org_names)
            })
    dataframes['author_groups'] = pd.DataFrame(author_groups_data)

    # Citation Information
    citation_info_obj = head.get('citation-info', {})

    citation_language = ''
    citation_type = ''

    if isinstance(citation_info_obj, dict):
        citation_language = citation_info_obj.get('citation-language', {})
        if isinstance(citation_language, dict):
            citation_language = citation_language.get('@language', '')
        else:
            citation_language = ''
        
        citation_type = citation_info_obj.get('citation-type', {})
        if isinstance(citation_type, dict):
            citation_type = citation_type.get('@code', '')
        else:
            citation_type = ''
    elif isinstance(citation_info_obj, list) and len(citation_info_obj) > 0:
        first_cit = citation_info_obj[0]
        if isinstance(first_cit, dict):
            citation_language = first_cit.get('citation-language', {})
            if isinstance(citation_language, dict):
                citation_language = citation_language.get('@language', '')
            else:
                citation_language = ''
            citation_type = first_cit.get('citation-type', {})
            if isinstance(citation_type, dict):
                citation_type = citation_type.get('@code', '')
            else:
                citation_type = ''
        else:
            citation_language = ''
            citation_type = ''
    else:
        citation_language = ''
        citation_type = ''

    citation_data = {
        'citation_language': [citation_language],
        'citation_type': [citation_type]
    }

    dataframes['citation_info'] = pd.DataFrame(citation_data)


    # Source Information
    source = head.get('source', {})

    publication_year = source.get('publicationyear', {})
    publication_date = source.get('publicationdate', {})

    # Handle website safely
    website_obj = source.get('website', {})
    if isinstance(website_obj, dict):
        website = website_obj.get('ce:e-address', {})
    elif isinstance(website_obj, list) and len(website_obj) > 0:
        # If it’s a list, take the first element
        website = website_obj[0].get('ce:e-address', {}) if isinstance(website_obj[0], dict) else {}
    else:
        website = {}

    # Handle publisher info safely
    publisher_info = source.get('publisher', {})
    if not isinstance(publisher_info, dict):
        publisher_info = {}
    
    # Extract publication date details
    date_text = publication_date.get('date-text', {})
    
    # Extract ISSNs with separate fields
    issns = ensure_list(source.get('issn', []))
    issn_electronic = ''
    issn_print = ''
    issn_types = []
    issn_values = []
    
    for issn in issns:
        if isinstance(issn, dict):
            issn_type = issn.get('@type', '')
            issn_value = issn.get('$', '')
            issn_types.append(issn_type)
            issn_values.append(issn_value)
            
            if issn_type == 'electronic':
                issn_electronic = issn_value
            elif issn_type == 'print':
                issn_print = issn_value
    # Safely handle publication date info
    if isinstance(publication_date, dict):
        date_text = publication_date.get('date-text', '')
        if isinstance(date_text, dict):
            pub_date = date_text.get('$', '')
        else:
            pub_date = str(date_text)
        
        pub_year_full = publication_date.get('year', '')
        pub_month = publication_date.get('month', '')
        pub_day = publication_date.get('day', '')
    else:
        # fallback if publication_date is a string
        pub_date = str(publication_date)
        pub_year_full = ''
        pub_month = ''
        pub_day = ''

    # Safely handle website
    if isinstance(website, dict):
        website_url = website.get('$', '')
    else:
        website_url = str(website)

    # Safely handle translated title
    translated_title_obj = source.get('translated-sourcetitle', '')
    if isinstance(translated_title_obj, dict):
        translated_title = translated_title_obj.get('$', '')
    else:
        translated_title = str(translated_title_obj)
    source_data = {
        'book_title': [source.get('sourcetitle', '')],
        'abbreviated_title': [source.get('sourcetitle-abbrev', '')],
        'publication_year': [publication_year.get('@first', '')],
        'publication_date': [pub_date],
        'publication_year_full': [pub_year_full],
        'publication_month': [pub_month],
        'publication_day': [pub_day],
        'website': [website_url],
        'publisher_name': [publisher_info.get('publishername', '')],
        'source_country': [source.get('@country', '')],
        'source_type': [source.get('@type', '')],
        'source_id': [source.get('@srcid', '')],
        'first_page': [source.get('volisspag', {}).get('pagerange', {}).get('@first', '')],
        'last_page': [source.get('volisspag', {}).get('pagerange', {}).get('@last', '')],
        'page_range': [f"{source.get('volisspag', {}).get('pagerange', {}).get('@first', '')}-{source.get('volisspag', {}).get('pagerange', {}).get('@last', '')}"],
        'issn_electronic': [issn_electronic],
        'issn_print': [issn_print],
        'issn_combined': ['; '.join([f"{issn_type}: {issn_value}" for issn_type, issn_value in zip(issn_types, issn_values)])],
        'issue_title': [source.get('issuetitle', '')],
        'translated_title': [translated_title]
    }
    dataframes['source_info'] = pd.DataFrame(source_data)

    # Correspondence Information
    correspondence_data = {}

    correspondence_obj = head.get('correspondence', {})

    if isinstance(correspondence_obj, dict):
        person = correspondence_obj.get('person', {})
        corr_affiliation = correspondence_obj.get('affiliation', {})
    elif isinstance(correspondence_obj, list) and len(correspondence_obj) > 0:
        # If list, take the first element
        first_corr = correspondence_obj[0]
        person = first_corr.get('person', {}) if isinstance(first_corr, dict) else {}
        corr_affiliation = first_corr.get('affiliation', {}) if isinstance(first_corr, dict) else {}
    else:
        person = {}
        corr_affiliation = {}

    corr_organizations = ensure_list(corr_affiliation.get('organization', []))
    corr_org_names = [org.get('$', '') for org in corr_organizations if isinstance(org, dict)]

    correspondence_data = {
        'correspondence_author': [f"{person.get('ce:given-name', '')} {person.get('ce:surname', '')}"],
        'correspondence_organizations': ['; '.join(corr_org_names)]
    }

    dataframes['correspondence'] = pd.DataFrame(correspondence_data)

    # 7. ITEM INFO (Identifiers and history)
    item_info = bibrecord.get('item-info', {})
    history = item_info.get('history', {}).get('date-created', {})
    
    # Item IDs
    item_ids = ensure_list(item_info.get('itemidlist', {}).get('itemid', []))
    itemid_data = []
    for itemid in item_ids:
        if isinstance(itemid, dict):
            itemid_data.append({
                'id_type': itemid.get('@idtype', ''),
                'id_value': itemid.get('$', '')
            })
    dataframes['item_ids'] = pd.DataFrame(itemid_data)
    
    # Database Collections
    db_collections = ensure_list(item_info.get('dbcollection', []))
    dbcollection_data = []
    for db in db_collections:
        if isinstance(db, dict):
            dbcollection_data.append({
                'database_name': db.get('$', '')
            })
    dataframes['database_collections'] = pd.DataFrame(dbcollection_data)

    item_info_data = {
        'copyright': [item_info.get('copyright', {}).get('$', '')],
        'doi': [item_info.get('itemidlist', {}).get('ce:doi', '')],
        'creation_year': [history.get('@year', '')],
        'creation_month': [history.get('@month', '')],
        'creation_day': [history.get('@day', '')],
        'creation_date': [f"{history.get('@year', '')}-{history.get('@month', '')}-{history.get('@day', '')}"]
    }
    dataframes['item_info'] = pd.DataFrame(item_info_data)

    # 8. REFERENCES DataFrame
    tail = bibrecord.get('tail') if isinstance(bibrecord.get('tail'), dict) else {}
    bibliography = tail.get('bibliography') if isinstance(tail.get('bibliography'), dict) else {}
    references = ensure_list(bibliography.get('reference', []))
    
    references_data = []
    for i, ref in enumerate(references):
        if isinstance(ref, dict):
            ref_info = ref.get('ref-info', {})
            
            # Extract authors with separate fields
            authors_data = []
            authors_info = ref_info.get('ref-authors', {})
            authors_list = ensure_list(authors_info.get('author', []))
            for author in authors_list:
                if isinstance(author, dict):
                    authors_data.append({
                        'sequence': author.get('@seq', ''),
                        'surname': author.get('ce:surname', ''),
                        'initials': author.get('ce:initials', ''),
                        'indexed_name': author.get('ce:indexed-name', '')
                    })
            
            # Extract publication year
            pub_year = ref_info.get('ref-publicationyear', {}).get('@first', '')
            
            # Extract title
            ref_title = ref_info.get('ref-title', {}).get('ref-titletext', '')
            
            # Extract volume and page info
            volisspag = ref_info.get('ref-volisspag', {})
            volume = volisspag.get('voliss', {}).get('@volume', '')
            page_range = volisspag.get('pagerange', {})
            first_page = page_range.get('@first', '')
            last_page = page_range.get('@last', '')
            
            # Extract source title
            source_title = ref_info.get('ref-sourcetitle', '')
            
            # Extract item IDs with separate fields
            item_ids_data = []
            itemidlist = ref_info.get('refd-itemidlist', {})
            itemid_items = ensure_list(itemidlist.get('itemid', []))
            for itemid in itemid_items:
                if isinstance(itemid, dict):
                    item_ids_data.append({
                        'id_type': itemid.get('@idtype', ''),
                        'id_value': itemid.get('$', '')
                    })
            
            # Prepare author strings
            author_names = [f"{auth['surname']} {auth['initials']}" for auth in authors_data]
            author_surnames = [auth['surname'] for auth in authors_data]
            author_initials = [auth['initials'] for auth in authors_data]
            
            # Prepare item ID strings
            item_id_types = [item['id_type'] for item in item_ids_data]
            item_id_values = [item['id_value'] for item in item_ids_data]
            
            references_data.append({
                'reference_number': i + 1,
                'reference_id': ref.get('@id', ''),
                'ref_fulltext': ref.get('ref-fulltext', '')[:500],
                
                # Author information - separated
                'authors_combined': '; '.join(author_names),
                'author_surnames': '; '.join(author_surnames),
                'author_initials': '; '.join(author_initials),
                'author_count': len(authors_data),
                'authors_full_data': authors_data,  # Keep full author data as list of dicts
                
                # Title and publication info
                'title': ref_title,
                'publication_year': pub_year,
                'volume': volume,
                'first_page': first_page,
                'last_page': last_page,
                'page_range': f"{first_page}-{last_page}" if first_page and last_page else '',
                'source_title': source_title,
                
                # Item IDs - separated
                'item_ids_combined': '; '.join([f"{item['id_type']}: {item['id_value']}" for item in item_ids_data]),
                'item_id_types': '; '.join(item_id_types),
                'item_id_values': '; '.join(item_id_values),
                'item_ids_full_data': item_ids_data,  # Keep full item ID data as list of dicts
                
                'ref_info': ref_info  # Keep the full ref-info as backup
            })
    dataframes['references'] = pd.DataFrame(references_data)
    
    references_summary_data = {
        'total_references': [bibliography.get('@refcount', '')]
    }
    dataframes['references_summary'] = pd.DataFrame(references_summary_data)

    # 9. CLASSIFICATION ENHANCEMENT DataFrame
    enhancement = head.get('enhancement', {})
    classification_group = enhancement.get('classificationgroup', {})
    classifications = ensure_list(classification_group.get('classifications', []))
    
    classification_data = []
    for classification in classifications:
        if isinstance(classification, dict):
            classification_data.append({
                'classification_type': classification.get('@type', ''),
                'classification_code': classification.get('classification', '')
            })
    dataframes['classifications'] = pd.DataFrame(classification_data)

    # 10. OTHER INFORMATION DataFrame
    language = ''
    lang_obj = root.get('language')
    if isinstance(lang_obj, dict):
        language = lang_obj.get('@xml:lang', '')


    head = (
    root.get("item", {})
        .get("bibrecord", {})
        .get("head", {})
)

    # Extract abstract
    abstracts = head.get("abstracts", "Not available")

    # Handle case when abstracts is a list of dicts
    if isinstance(abstracts, list):
        # Usually Elsevier puts the text under the "$" key
        abstracts_text = " ".join([a.get("$", "") for a in abstracts])
    elif isinstance(abstracts, str):
        abstracts_text = abstracts
    else:
        abstracts_text = "Not available"
    dc_identifier = root.get('coredata', {}).get('dc:identifier', 'Not available')
    prism_publicationName = root.get('coredata', {}).get('prism:publicationName', 'Not available')

    
    other_data = {
        'language': [language],
        "abstracts": [abstracts_text],
        'author_keywords': [str(root.get('authkeywords', 'Not available'))],
        'index_terms': [str(root.get('idxterms', 'Not available'))],
        'dc:identifier': [dc_identifier],
        'prism:publicationName' : [prism_publicationName]
    }
    dataframes['other_info'] = pd.DataFrame(other_data)

    return dataframes

# %%
folder_path = r"d:\projectData\ScopusData2018-2023\2023"

# Get all JSON files
json_files = [
    os.path.join(folder_path, f)
    for f in os.listdir(folder_path)
    if os.path.isfile(os.path.join(folder_path, f))
]

print(f"Loaded {len(json_files)} JSON files")

all_results = []   # will store every file's extracted dataframes

for idx, file_path in enumerate(json_files, start=1):
    print(f"\n===== Processing file {idx}/{len(json_files)}: {file_path}")

    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
    except Exception as e:
        print(f"Error reading {file_path}: {e}")
        continue

    # Extract DataFrames
    dataframes = extract_all_to_dataframes(data)

    if not dataframes:
        print(f"Skipped {file_path} (structure mismatch)")
        continue

    # Store result (include filename for tracking)
    all_results.append({
        "file": os.path.basename(file_path),
        "dataframes": dataframes
    })

print("\n=====================================")
print(f"Finished processing {len(all_results)} valid files out of {len(json_files)}")
# Out:
# Loaded 2890 JSON files
#
# ===== Processing file 1/2890: d:\projectData\ScopusData2018-2023\2023\202300000
#
# ===== Processing file 2/2890: d:\projectData\ScopusData2018-2023\2023\202300001
#
# ===== Processing file 3/2890: d:\projectData\ScopusData2018-2023\2023\202300002
#
# ===== Processing file 4/2890: d:\projectData\ScopusData2018-2023\2023\202300003
#
# ===== Processing file 5/2890: d:\projectData\ScopusData2018-2023\2023\202300004
#
# ===== Processing file 6/2890: d:\projectData\ScopusData2018-2023\2023\202300005
#
# ===== Processing file 7/2890: d:\projectData\ScopusData2018-2023\2023\202300006
#
# ===== Processing file 8/2890: d:\projectData\ScopusData2018-2023\2023\202300007
#
# ===== Processing file 9/2890: d:\projectData\ScopusData2018-2023\2023\202300008
#
# ===== Processing file 10/2890: d:\projectData\ScopusData2018-2023\2023\202300009
#
# ===== Processing file 11/2890: d:\projectData\ScopusData2018-2023\2023\202300010
#
# ===== Processing file 12/2890: d:\projectData\ScopusData2018-2023\2023\202300011
#
# ===== Processing file 13/2890: d:\projectData\ScopusData2018-2023\2023\202300012
#
# ===== Processing file 14/2890: d:\projectData\ScopusData2018-2023\2023\202300013
#
# ===== Processing file 15/2890: d:\projectData\ScopusData2018-2023\2023\202300014
#
# ===== Processing file 16/2890: d:\projectData\ScopusData2018-2023\2023\202300015
#
# ===== Processing file 17/2890: d:\projectData\ScopusData2018-2023\2023\202300016
#
# ===== Processing file 18/2890: d:\projectData\ScopusData2018-2023\2023\202300017
#
# ===== Processing file 19/2890: d:\projectData\ScopusData2018-2023\2023\202300018
#
# ===== Processing file 20/2890: d:\projectData\ScopusData2018-2023\2023\202300019
#
# ===== Processing file 21/2890: d:\projectData\ScopusData2018-2023\2023\202300020
#
# ===== Processing file 22/2890: d:\projectData\ScopusData2018-2023\2023\202300021
#
# ===== Processing file 23/2890: d:\projectData\ScopusData2018-2023\2023\202300022
#
# ===== Processing file 24/2890: d:\projectData\ScopusData2018-2023\2023\202300023
#
# ===== Processing file 25/2890: d:\projectData\ScopusData2018-2023\2023\202300024
#
# ===== Processing file 26/2890: d:\projectData\ScopusData2018-2023\2023\202300025
#
# ===== Processing file 27/2890: d:\projectData\ScopusData2018-2023\2023\202300026
#
# ===== Processing file 28/2890: d:\projectData\ScopusData2018-2023\2023\202300027
#
# ===== Processing file 29/2890: d:\projectData\ScopusData2018-2023\2023\202300028
#
# ===== Processing file 30/2890: d:\projectData\ScopusData2018-2023\2023\202300029
#
# ===== Processing file 31/2890: d:\projectData\ScopusData2018-2023\2023\202300030
#
# ===== Processing file 32/2890: d:\projectData\ScopusData2018-2023\2023\202300031
#
# ===== Processing file 33/2890: d:\projectData\ScopusData2018-2023\2023\202300032
#
# ===== Processing file 34/2890: d:\projectData\ScopusData2018-2023\2023\202300033
#
# ===== Processing file 35/2890: d:\projectData\ScopusData2018-2023\2023\202300034
#
# ===== Processing file 36/2890: d:\projectData\ScopusData2018-2023\2023\202300035
#
# ===== Processing file 37/2890: d:\projectData\ScopusData2018-2023\2023\202300036
#
# ===== Processing file 38/2890: d:\projectData\ScopusData2018-2023\2023\202300037
#
# ===== Processing file 39/2890: d:\projectData\ScopusData2018-2023\2023\202300038
#
# ===== Processing file 40/2890: d:\projectData\ScopusData2018-2023\2023\202300039
#
# ===== Processing file 41/2890: d:\projectData\ScopusData2018-2023\2023\202300040
#
# ===== Processing file 42/2890: d:\projectData\ScopusData2018-2023\2023\202300041
#
# ===== Processing file 43/2890: d:\projectData\ScopusData2018-2023\2023\202300042
#
# ===== Processing file 44/2890: d:\projectData\ScopusData2018-2023\2023\202300043
#
# ===== Processing file 45/2890: d:\projectData\ScopusData2018-2023\2023\202300044
#
# ===== Processing file 46/2890: d:\projectData\ScopusData2018-2023\2023\202300045
#
# ===== Processing file 47/2890: d:\projectData\ScopusData2018-2023\2023\202300046
#
# ===== Processing file 48/2890: d:\projectData\ScopusData2018-2023\2023\202300047
#
# ===== Processing file 49/2890: d:\projectData\ScopusData2018-2023\2023\202300048
#
# ===== Processing file 50/2890: d:\projectData\ScopusData2018-2023\2023\202300049
#
# ===== Processing file 51/2890: d:\projectData\ScopusData2018-2023\2023\202300050
#
# ===== Processing file 52/2890: d:\projectData\ScopusData2018-2023\2023\202300051
#
# ===== Processing file 53/2890: d:\projectData\ScopusData2018-2023\2023\202300052
#
# ===== Processing file 54/2890: d:\projectData\ScopusData2018-2023\2023\202300053
#
# ===== Processing file 55/2890: d:\projectData\ScopusData2018-2023\2023\202300054
#
# ===== Processing file 56/2890: d:\projectData\ScopusData2018-2023\2023\202300055
#
# ===== Processing file 57/2890: d:\projectData\ScopusData2018-2023\2023\202300056
#
# ===== Processing file 58/2890: d:\projectData\ScopusData2018-2023\2023\202300057
#
# ===== Processing file 59/2890: d:\projectData\ScopusData2018-2023\2023\202300058
#
# ===== Processing file 60/2890: d:\projectData\ScopusData2018-2023\2023\202300059
#
# ===== Processing file 61/2890: d:\projectData\ScopusData2018-2023\2023\202300060
#
# ===== Processing file 62/2890: d:\projectData\ScopusData2018-2023\2023\202300061
#
# ===== Processing file 63/2890: d:\projectData\ScopusData2018-2023\2023\202300062
#
# ===== Processing file 64/2890: d:\projectData\ScopusData2018-2023\2023\202300063
#
# ===== Processing file 65/2890: d:\projectData\ScopusData2018-2023\2023\202300064
#
# ===== Processing file 66/2890: d:\projectData\ScopusData2018-2023\2023\202300065
#
# ===== Processing file 67/2890: d:\projectData\ScopusData2018-2023\2023\202300066
#
# ===== Processing file 68/2890: d:\projectData\ScopusData2018-2023\2023\202300067
#
# ===== Processing file 69/2890: d:\projectData\ScopusData2018-2023\2023\202300068
#
# ===== Processing file 70/2890: d:\projectData\ScopusData2018-2023\2023\202300069
#
# ===== Processing file 71/2890: d:\projectData\ScopusData2018-2023\2023\202300070
#
# ===== Processing file 72/2890: d:\projectData\ScopusData2018-2023\2023\202300071
#
# ===== Processing file 73/2890: d:\projectData\ScopusData2018-2023\2023\202300072
#
# ===== Processing file 74/2890: d:\projectData\ScopusData2018-2023\2023\202300073
#
# ===== Processing file 75/2890: d:\projectData\ScopusData2018-2023\2023\202300074
#
# ===== Processing file 76/2890: d:\projectData\ScopusData2018-2023\2023\202300075
#
# ===== Processing file 77/2890: d:\projectData\ScopusData2018-2023\2023\202300076
#
# ===== Processing file 78/2890: d:\projectData\ScopusData2018-2023\2023\202300077
#
# ===== Processing file 79/2890: d:\projectData\ScopusData2018-2023\2023\202300078
#
# ===== Processing file 80/2890: d:\projectData\ScopusData2018-2023\2023\202300079
#
# ===== Processing file 81/2890: d:\projectData\ScopusData2018-2023\2023\202300080
#
# ===== Processing file 82/2890: d:\projectData\ScopusData2018-2023\2023\202300081
#
# ===== Processing file 83/2890: d:\projectData\ScopusData2018-2023\2023\202300082
#
# ===== Processing file 84/2890: d:\projectData\ScopusData2018-2023\2023\202300083
#
# ===== Processing file 85/2890: d:\projectData\ScopusData2018-2023\2023\202300084
#
# ===== Processing file 86/2890: d:\projectData\ScopusData2018-2023\2023\202300085
#
# ===== Processing file 87/2890: d:\projectData\ScopusData2018-2023\2023\202300086
#
# ===== Processing file 88/2890: d:\projectData\ScopusData2018-2023\2023\202300087
#
# ===== Processing file 89/2890: d:\projectData\ScopusData2018-2023\2023\202300088
#
# ===== Processing file 90/2890: d:\projectData\ScopusData2018-2023\2023\202300089
#
# ===== Processing file 91/2890: d:\projectData\ScopusData2018-2023\2023\202300090
#
# ===== Processing file 92/2890: d:\projectData\ScopusData2018-2023\2023\202300091
#
# ===== Processing file 93/2890: d:\projectData\ScopusData2018-2023\2023\202300092
#
# ===== Processing file 94/2890: d:\projectData\ScopusData2018-2023\2023\202300093
#
# ===== Processing file 95/2890: d:\projectData\ScopusData2018-2023\2023\202300094
#
# ===== Processing file 96/2890: d:\projectData\ScopusData2018-2023\2023\202300095
#
# ===== Processing file 97/2890: d:\projectData\ScopusData2018-2023\2023\202300096
#
# ===== Processing file 98/2890: d:\projectData\ScopusData2018-2023\2023\202300097
#
# ===== Processing file 99/2890: d:\projectData\ScopusData2018-2023\2023\202300098
#
# ===== Processing file 100/2890: d:\projectData\ScopusData2018-2023\2023\202300099
#
# ===== Processing file 101/2890: d:\projectData\ScopusData2018-2023\2023\202300100
#
# ===== Processing file 102/2890: d:\projectData\ScopusData2018-2023\2023\202300101
#
# ===== Processing file 103/2890: d:\projectData\ScopusData2018-2023\2023\202300102
#
# ===== Processing file 104/2890: d:\projectData\ScopusData2018-2023\2023\202300103
#
# ===== Processing file 105/2890: d:\projectData\ScopusData2018-2023\2023\202300104
#
# ===== Processing file 106/2890: d:\projectData\ScopusData2018-2023\2023\202300105
#
# ===== Processing file 107/2890: d:\projectData\ScopusData2018-2023\2023\202300106
#
# ===== Processing file 108/2890: d:\projectData\ScopusData2018-2023\2023\202300107
#
# ===== Processing file 109/2890: d:\projectData\ScopusData2018-2023\2023\202300108
#
# ===== Processing file 110/2890: d:\projectData\ScopusData2018-2023\2023\202300109
#
# ===== Processing file 111/2890: d:\projectData\ScopusData2018-2023\2023\202300110
#
# ===== Processing file 112/2890: d:\projectData\ScopusData2018-2023\2023\202300111
#
# ===== Processing file 113/2890: d:\projectData\ScopusData2018-2023\2023\202300112
#
# ===== Processing file 114/2890: d:\projectData\ScopusData2018-2023\2023\202300113
#
# ===== Processing file 115/2890: d:\projectData\ScopusData2018-2023\2023\202300114
#
# ===== Processing file 116/2890: d:\projectData\ScopusData2018-2023\2023\202300115
#
# ===== Processing file 117/2890: d:\projectData\ScopusData2018-2023\2023\202300116
#
# ===== Processing file 118/2890: d:\projectData\ScopusData2018-2023\2023\202300117
#
# ===== Processing file 119/2890: d:\projectData\ScopusData2018-2023\2023\202300118
#
# ===== Processing file 120/2890: d:\projectData\ScopusData2018-2023\2023\202300119
#
# ===== Processing file 121/2890: d:\projectData\ScopusData2018-2023\2023\202300120
#
# ===== Processing file 122/2890: d:\projectData\ScopusData2018-2023\2023\202300121
#
# ===== Processing file 123/2890: d:\projectData\ScopusData2018-2023\2023\202300122
#
# ===== Processing file 124/2890: d:\projectData\ScopusData2018-2023\2023\202300123
#
# ===== Processing file 125/2890: d:\projectData\ScopusData2018-2023\2023\202300124
#
# ===== Processing file 126/2890: d:\projectData\ScopusData2018-2023\2023\202300125
#
# ===== Processing file 127/2890: d:\projectData\ScopusData2018-2023\2023\202300126
#
# ===== Processing file 128/2890: d:\projectData\ScopusData2018-2023\2023\202300127
#
# ===== Processing file 129/2890: d:\projectData\ScopusData2018-2023\2023\202300128
#
# ===== Processing file 130/2890: d:\projectData\ScopusData2018-2023\2023\202300129
#
# ===== Processing file 131/2890: d:\projectData\ScopusData2018-2023\2023\202300130
#
# ===== Processing file 132/2890: d:\projectData\ScopusData2018-2023\2023\202300131
#
# ===== Processing file 133/2890: d:\projectData\ScopusData2018-2023\2023\202300132
#
# ===== Processing file 134/2890: d:\projectData\ScopusData2018-2023\2023\202300133
#
# ===== Processing file 135/2890: d:\projectData\ScopusData2018-2023\2023\202300134
#
# ===== Processing file 136/2890: d:\projectData\ScopusData2018-2023\2023\202300135
#
# ===== Processing file 137/2890: d:\projectData\ScopusData2018-2023\2023\202300136
#
# ===== Processing file 138/2890: d:\projectData\ScopusData2018-2023\2023\202300137
#
# ===== Processing file 139/2890: d:\projectData\ScopusData2018-2023\2023\202300138
#
# ===== Processing file 140/2890: d:\projectData\ScopusData2018-2023\2023\202300139
#
# ===== Processing file 141/2890: d:\projectData\ScopusData2018-2023\2023\202300140
#
# ===== Processing file 142/2890: d:\projectData\ScopusData2018-2023\2023\202300141
#
# ===== Processing file 143/2890: d:\projectData\ScopusData2018-2023\2023\202300142
#
# ===== Processing file 144/2890: d:\projectData\ScopusData2018-2023\2023\202300143
#
# ===== Processing file 145/2890: d:\projectData\ScopusData2018-2023\2023\202300144
#
# ===== Processing file 146/2890: d:\projectData\ScopusData2018-2023\2023\202300145
#
# ===== Processing file 147/2890: d:\projectData\ScopusData2018-2023\2023\202300146
#
# ===== Processing file 148/2890: d:\projectData\ScopusData2018-2023\2023\202300147
#
# ===== Processing file 149/2890: d:\projectData\ScopusData2018-2023\2023\202300148
#
# ===== Processing file 150/2890: d:\projectData\ScopusData2018-2023\2023\202300149
#
# ===== Processing file 151/2890: d:\projectData\ScopusData2018-2023\2023\202300150
#
# ===== Processing file 152/2890: d:\projectData\ScopusData2018-2023\2023\202300151
#
# ===== Processing file 153/2890: d:\projectData\ScopusData2018-2023\2023\202300152
#
# ===== Processing file 154/2890: d:\projectData\ScopusData2018-2023\2023\202300153
#
# ===== Processing file 155/2890: d:\projectData\ScopusData2018-2023\2023\202300154
#
# ===== Processing file 156/2890: d:\projectData\ScopusData2018-2023\2023\202300155
#
# ===== Processing file 157/2890: d:\projectData\ScopusData2018-2023\2023\202300156
#
# ===== Processing file 158/2890: d:\projectData\ScopusData2018-2023\2023\202300157
#
# ===== Processing file 159/2890: d:\projectData\ScopusData2018-2023\2023\202300158
#
# ===== Processing file 160/2890: d:\projectData\ScopusData2018-2023\2023\202300159
#
# ===== Processing file 161/2890: d:\projectData\ScopusData2018-2023\2023\202300160
#
# ===== Processing file 162/2890: d:\projectData\ScopusData2018-2023\2023\202300161
#
# ===== Processing file 163/2890: d:\projectData\ScopusData2018-2023\2023\202300162
#
# ===== Processing file 164/2890: d:\projectData\ScopusData2018-2023\2023\202300163
#
# ===== Processing file 165/2890: d:\projectData\ScopusData2018-2023\2023\202300164
#
# ===== Processing file 166/2890: d:\projectData\ScopusData2018-2023\2023\202300165
#
# ===== Processing file 167/2890: d:\projectData\ScopusData2018-2023\2023\202300166
#
# ===== Processing file 168/2890: d:\projectData\ScopusData2018-2023\2023\202300167
#
# ===== Processing file 169/2890: d:\projectData\ScopusData2018-2023\2023\202300168
#
# ===== Processing file 170/2890: d:\projectData\ScopusData2018-2023\2023\202300169
#
# ===== Processing file 171/2890: d:\projectData\ScopusData2018-2023\2023\202300170
#
# ===== Processing file 172/2890: d:\projectData\ScopusData2018-2023\2023\202300171
#
# ===== Processing file 173/2890: d:\projectData\ScopusData2018-2023\2023\202300172
#
# ===== Processing file 174/2890: d:\projectData\ScopusData2018-2023\2023\202300173
#
# ===== Processing file 175/2890: d:\projectData\ScopusData2018-2023\2023\202300174
#
# ===== Processing file 176/2890: d:\projectData\ScopusData2018-2023\2023\202300175
#
# ===== Processing file 177/2890: d:\projectData\ScopusData2018-2023\2023\202300176
#
# ===== Processing file 178/2890: d:\projectData\ScopusData2018-2023\2023\202300177
#
# ===== Processing file 179/2890: d:\projectData\ScopusData2018-2023\2023\202300178
#
# ===== Processing file 180/2890: d:\projectData\ScopusData2018-2023\2023\202300179
#
# ===== Processing file 181/2890: d:\projectData\ScopusData2018-2023\2023\202300180
#
# ===== Processing file 182/2890: d:\projectData\ScopusData2018-2023\2023\202300181
#
# ===== Processing file 183/2890: d:\projectData\ScopusData2018-2023\2023\202300182
#
# ===== Processing file 184/2890: d:\projectData\ScopusData2018-2023\2023\202300183
#
# ===== Processing file 185/2890: d:\projectData\ScopusData2018-2023\2023\202300184
#
# ===== Processing file 186/2890: d:\projectData\ScopusData2018-2023\2023\202300185
#
# ===== Processing file 187/2890: d:\projectData\ScopusData2018-2023\2023\202300186
#
# ===== Processing file 188/2890: d:\projectData\ScopusData2018-2023\2023\202300187
#
# ===== Processing file 189/2890: d:\projectData\ScopusData2018-2023\2023\202300188
#
# ===== Processing file 190/2890: d:\projectData\ScopusData2018-2023\2023\202300189
#
# ===== Processing file 191/2890: d:\projectData\ScopusData2018-2023\2023\202300190
#
# ===== Processing file 192/2890: d:\projectData\ScopusData2018-2023\2023\202300191
#
# ===== Processing file 193/2890: d:\projectData\ScopusData2018-2023\2023\202300192
#
# ===== Processing file 194/2890: d:\projectData\ScopusData2018-2023\2023\202300193
#
# ===== Processing file 195/2890: d:\projectData\ScopusData2018-2023\2023\202300194
#
# ===== Processing file 196/2890: d:\projectData\ScopusData2018-2023\2023\202300195
#
# ===== Processing file 197/2890: d:\projectData\ScopusData2018-2023\2023\202300196
#
# ===== Processing file 198/2890: d:\projectData\ScopusData2018-2023\2023\202300197
#
# ===== Processing file 199/2890: d:\projectData\ScopusData2018-2023\2023\202300198
#
# ===== Processing file 200/2890: d:\projectData\ScopusData2018-2023\2023\202300199
#
# ===== Processing file 201/2890: d:\projectData\ScopusData2018-2023\2023\202300200
#
# ===== Processing file 202/2890: d:\projectData\ScopusData2018-2023\2023\202300201
#
# ===== Processing file 203/2890: d:\projectData\ScopusData2018-2023\2023\202300202
#
# ===== Processing file 204/2890: d:\projectData\ScopusData2018-2023\2023\202300203
#
# ===== Processing file 205/2890: d:\projectData\ScopusData2018-2023\2023\202300204
#
# ===== Processing file 206/2890: d:\projectData\ScopusData2018-2023\2023\202300205
#
# ===== Processing file 207/2890: d:\projectData\ScopusData2018-2023\2023\202300206
#
# ===== Processing file 208/2890: d:\projectData\ScopusData2018-2023\2023\202300207
#
# ===== Processing file 209/2890: d:\projectData\ScopusData2018-2023\2023\202300208
#
# ===== Processing file 210/2890: d:\projectData\ScopusData2018-2023\2023\202300209
#
# ===== Processing file 211/2890: d:\projectData\ScopusData2018-2023\2023\202300210
#
# ===== Processing file 212/2890: d:\projectData\ScopusData2018-2023\2023\202300211
#
# ===== Processing file 213/2890: d:\projectData\ScopusData2018-2023\2023\202300212
#
# ===== Processing file 214/2890: d:\projectData\ScopusData2018-2023\2023\202300213
#
# ===== Processing file 215/2890: d:\projectData\ScopusData2018-2023\2023\202300214
#
# ===== Processing file 216/2890: d:\projectData\ScopusData2018-2023\2023\202300215
#
# ===== Processing file 217/2890: d:\projectData\ScopusData2018-2023\2023\202300216
#
# ===== Processing file 218/2890: d:\projectData\ScopusData2018-2023\2023\202300217
#
# ===== Processing file 219/2890: d:\projectData\ScopusData2018-2023\2023\202300218
#
# ===== Processing file 220/2890: d:\projectData\ScopusData2018-2023\2023\202300219
#
# ===== Processing file 221/2890: d:\projectData\ScopusData2018-2023\2023\202300220
#
# ===== Processing file 222/2890: d:\projectData\ScopusData2018-2023\2023\202300221
#
# ===== Processing file 223/2890: d:\projectData\ScopusData2018-2023\2023\202300222
#
# ===== Processing file 224/2890: d:\projectData\ScopusData2018-2023\2023\202300223
#
# ===== Processing file 225/2890: d:\projectData\ScopusData2018-2023\2023\202300224
#
# ===== Processing file 226/2890: d:\projectData\ScopusData2018-2023\2023\202300225
#
# ===== Processing file 227/2890: d:\projectData\ScopusData2018-2023\2023\202300226
#
# ===== Processing file 228/2890: d:\projectData\ScopusData2018-2023\2023\202300227
#
# ===== Processing file 229/2890: d:\projectData\ScopusData2018-2023\2023\202300228
#
# ===== Processing file 230/2890: d:\projectData\ScopusData2018-2023\2023\202300229
#
# ===== Processing file 231/2890: d:\projectData\ScopusData2018-2023\2023\202300230
#
# ===== Processing file 232/2890: d:\projectData\ScopusData2018-2023\2023\202300231
#
# ===== Processing file 233/2890: d:\projectData\ScopusData2018-2023\2023\202300232
#
# ===== Processing file 234/2890: d:\projectData\ScopusData2018-2023\2023\202300233
#
# ===== Processing file 235/2890: d:\projectData\ScopusData2018-2023\2023\202300234
#
# ===== Processing file 236/2890: d:\projectData\ScopusData2018-2023\2023\202300235
#
# ===== Processing file 237/2890: d:\projectData\ScopusData2018-2023\2023\202300236
#
# ===== Processing file 238/2890: d:\projectData\ScopusData2018-2023\2023\202300237
#
# ===== Processing file 239/2890: d:\projectData\ScopusData2018-2023\2023\202300238
#
# ===== Processing file 240/2890: d:\projectData\ScopusData2018-2023\2023\202300239
#
# ===== Processing file 241/2890: d:\projectData\ScopusData2018-2023\2023\202300240
#
# ===== Processing file 242/2890: d:\projectData\ScopusData2018-2023\2023\202300241
#
# ===== Processing file 243/2890: d:\projectData\ScopusData2018-2023\2023\202300242
#
# ===== Processing file 244/2890: d:\projectData\ScopusData2018-2023\2023\202300243
#
# ===== Processing file 245/2890: d:\projectData\ScopusData2018-2023\2023\202300244
#
# ===== Processing file 246/2890: d:\projectData\ScopusData2018-2023\2023\202300245
#
# ===== Processing file 247/2890: d:\projectData\ScopusData2018-2023\2023\202300246
#
# ===== Processing file 248/2890: d:\projectData\ScopusData2018-2023\2023\202300247
#
# ===== Processing file 249/2890: d:\projectData\ScopusData2018-2023\2023\202300248
#
# ===== Processing file 250/2890: d:\projectData\ScopusData2018-2023\2023\202300249
#
# ===== Processing file 251/2890: d:\projectData\ScopusData2018-2023\2023\202300250
#
# ===== Processing file 252/2890: d:\projectData\ScopusData2018-2023\2023\202300251
#
# ===== Processing file 253/2890: d:\projectData\ScopusData2018-2023\2023\202300252
#
# ===== Processing file 254/2890: d:\projectData\ScopusData2018-2023\2023\202300253
#
# ===== Processing file 255/2890: d:\projectData\ScopusData2018-2023\2023\202300254
#
# ===== Processing file 256/2890: d:\projectData\ScopusData2018-2023\2023\202300255
#
# ===== Processing file 257/2890: d:\projectData\ScopusData2018-2023\2023\202300256
#
# ===== Processing file 258/2890: d:\projectData\ScopusData2018-2023\2023\202300257
#
# ===== Processing file 259/2890: d:\projectData\ScopusData2018-2023\2023\202300258
#
# ===== Processing file 260/2890: d:\projectData\ScopusData2018-2023\2023\202300259
#
# ===== Processing file 261/2890: d:\projectData\ScopusData2018-2023\2023\202300260
#
# ===== Processing file 262/2890: d:\projectData\ScopusData2018-2023\2023\202300261
#
# ===== Processing file 263/2890: d:\projectData\ScopusData2018-2023\2023\202300262
#
# ===== Processing file 264/2890: d:\projectData\ScopusData2018-2023\2023\202300263
#
# ===== Processing file 265/2890: d:\projectData\ScopusData2018-2023\2023\202300264
#
# ===== Processing file 266/2890: d:\projectData\ScopusData2018-2023\2023\202300265
#
# ===== Processing file 267/2890: d:\projectData\ScopusData2018-2023\2023\202300266
#
# ===== Processing file 268/2890: d:\projectData\ScopusData2018-2023\2023\202300267
#
# ===== Processing file 269/2890: d:\projectData\ScopusData2018-2023\2023\202300268
#
# ===== Processing file 270/2890: d:\projectData\ScopusData2018-2023\2023\202300269
#
# ===== Processing file 271/2890: d:\projectData\ScopusData2018-2023\2023\202300270
#
# ===== Processing file 272/2890: d:\projectData\ScopusData2018-2023\2023\202300271
#
# ===== Processing file 273/2890: d:\projectData\ScopusData2018-2023\2023\202300272
#
# ===== Processing file 274/2890: d:\projectData\ScopusData2018-2023\2023\202300273
#
# ===== Processing file 275/2890: d:\projectData\ScopusData2018-2023\2023\202300274
#
# ===== Processing file 276/2890: d:\projectData\ScopusData2018-2023\2023\202300275
#
# ===== Processing file 277/2890: d:\projectData\ScopusData2018-2023\2023\202300276
#
# ===== Processing file 278/2890: d:\projectData\ScopusData2018-2023\2023\202300277
#
# ===== Processing file 279/2890: d:\projectData\ScopusData2018-2023\2023\202300278
#
# ===== Processing file 280/2890: d:\projectData\ScopusData2018-2023\2023\202300279
#
# ===== Processing file 281/2890: d:\projectData\ScopusData2018-2023\2023\202300280
#
# ===== Processing file 282/2890: d:\projectData\ScopusData2018-2023\2023\202300281
#
# ===== Processing file 283/2890: d:\projectData\ScopusData2018-2023\2023\202300282
#
# ===== Processing file 284/2890: d:\projectData\ScopusData2018-2023\2023\202300283
#
# ===== Processing file 285/2890: d:\projectData\ScopusData2018-2023\2023\202300284
#
# ===== Processing file 286/2890: d:\projectData\ScopusData2018-2023\2023\202300285
#
# ===== Processing file 287/2890: d:\projectData\ScopusData2018-2023\2023\202300286
#
# ===== Processing file 288/2890: d:\projectData\ScopusData2018-2023\2023\202300287
#
# ===== Processing file 289/2890: d:\projectData\ScopusData2018-2023\2023\202300288
#
# ===== Processing file 290/2890: d:\projectData\ScopusData2018-2023\2023\202300289
#
# ===== Processing file 291/2890: d:\projectData\ScopusData2018-2023\2023\202300290
#
# ===== Processing file 292/2890: d:\projectData\ScopusData2018-2023\2023\202300291
#
# ===== Processing file 293/2890: d:\projectData\ScopusData2018-2023\2023\202300292
#
# ===== Processing file 294/2890: d:\projectData\ScopusData2018-2023\2023\202300293
#
# ===== Processing file 295/2890: d:\projectData\ScopusData2018-2023\2023\202300294
#
# ===== Processing file 296/2890: d:\projectData\ScopusData2018-2023\2023\202300295
#
# ===== Processing file 297/2890: d:\projectData\ScopusData2018-2023\2023\202300296
#
# ===== Processing file 298/2890: d:\projectData\ScopusData2018-2023\2023\202300297
#
# ===== Processing file 299/2890: d:\projectData\ScopusData2018-2023\2023\202300298
#
# ===== Processing file 300/2890: d:\projectData\ScopusData2018-2023\2023\202300299
#
# ===== Processing file 301/2890: d:\projectData\ScopusData2018-2023\2023\202300300
#
# ===== Processing file 302/2890: d:\projectData\ScopusData2018-2023\2023\202300301
#
# ===== Processing file 303/2890: d:\projectData\ScopusData2018-2023\2023\202300302
#
# ===== Processing file 304/2890: d:\projectData\ScopusData2018-2023\2023\202300303
#
# ===== Processing file 305/2890: d:\projectData\ScopusData2018-2023\2023\202300304
#
# ===== Processing file 306/2890: d:\projectData\ScopusData2018-2023\2023\202300305
#
# ===== Processing file 307/2890: d:\projectData\ScopusData2018-2023\2023\202300306
#
# ===== Processing file 308/2890: d:\projectData\ScopusData2018-2023\2023\202300307
#
# ===== Processing file 309/2890: d:\projectData\ScopusData2018-2023\2023\202300308
#
# ===== Processing file 310/2890: d:\projectData\ScopusData2018-2023\2023\202300309
#
# ===== Processing file 311/2890: d:\projectData\ScopusData2018-2023\2023\202300310
#
# ===== Processing file 312/2890: d:\projectData\ScopusData2018-2023\2023\202300311
#
# ===== Processing file 313/2890: d:\projectData\ScopusData2018-2023\2023\202300312
#
# ===== Processing file 314/2890: d:\projectData\ScopusData2018-2023\2023\202300313
#
# ===== Processing file 315/2890: d:\projectData\ScopusData2018-2023\2023\202300314
#
# ===== Processing file 316/2890: d:\projectData\ScopusData2018-2023\2023\202300315
#
# ===== Processing file 317/2890: d:\projectData\ScopusData2018-2023\2023\202300316
#
# ===== Processing file 318/2890: d:\projectData\ScopusData2018-2023\2023\202300317
#
# ===== Processing file 319/2890: d:\projectData\ScopusData2018-2023\2023\202300318
#
# ===== Processing file 320/2890: d:\projectData\ScopusData2018-2023\2023\202300319
#
# ===== Processing file 321/2890: d:\projectData\ScopusData2018-2023\2023\202300320
#
# ===== Processing file 322/2890: d:\projectData\ScopusData2018-2023\2023\202300321
#
# ===== Processing file 323/2890: d:\projectData\ScopusData2018-2023\2023\202300322
#
# ===== Processing file 324/2890: d:\projectData\ScopusData2018-2023\2023\202300323
#
# ===== Processing file 325/2890: d:\projectData\ScopusData2018-2023\2023\202300324
#
# ===== Processing file 326/2890: d:\projectData\ScopusData2018-2023\2023\202300325
#
# ===== Processing file 327/2890: d:\projectData\ScopusData2018-2023\2023\202300326
#
# ===== Processing file 328/2890: d:\projectData\ScopusData2018-2023\2023\202300327
#
# ===== Processing file 329/2890: d:\projectData\ScopusData2018-2023\2023\202300328
#
# ===== Processing file 330/2890: d:\projectData\ScopusData2018-2023\2023\202300329
#
# ===== Processing file 331/2890: d:\projectData\ScopusData2018-2023\2023\202300330
#
# ===== Processing file 332/2890: d:\projectData\ScopusData2018-2023\2023\202300331
#
# ===== Processing file 333/2890: d:\projectData\ScopusData2018-2023\2023\202300332
#
# ===== Processing file 334/2890: d:\projectData\ScopusData2018-2023\2023\202300333
#
# ===== Processing file 335/2890: d:\projectData\ScopusData2018-2023\2023\202300334
#
# ===== Processing file 336/2890: d:\projectData\ScopusData2018-2023\2023\202300335
#
# ===== Processing file 337/2890: d:\projectData\ScopusData2018-2023\2023\202300336
#
# ===== Processing file 338/2890: d:\projectData\ScopusData2018-2023\2023\202300337
#
# ===== Processing file 339/2890: d:\projectData\ScopusData2018-2023\2023\202300338
#
# ===== Processing file 340/2890: d:\projectData\ScopusData2018-2023\2023\202300339
#
# ===== Processing file 341/2890: d:\projectData\ScopusData2018-2023\2023\202300340
#
# ===== Processing file 342/2890: d:\projectData\ScopusData2018-2023\2023\202300341
#
# ===== Processing file 343/2890: d:\projectData\ScopusData2018-2023\2023\202300342
#
# ===== Processing file 344/2890: d:\projectData\ScopusData2018-2023\2023\202300343
#
# ===== Processing file 345/2890: d:\projectData\ScopusData2018-2023\2023\202300344
#
# ===== Processing file 346/2890: d:\projectData\ScopusData2018-2023\2023\202300345
#
# ===== Processing file 347/2890: d:\projectData\ScopusData2018-2023\2023\202300346
#
# ===== Processing file 348/2890: d:\projectData\ScopusData2018-2023\2023\202300347
#
# ===== Processing file 349/2890: d:\projectData\ScopusData2018-2023\2023\202300348
#
# ===== Processing file 350/2890: d:\projectData\ScopusData2018-2023\2023\202300349
#
# ===== Processing file 351/2890: d:\projectData\ScopusData2018-2023\2023\202300350
#
# ===== Processing file 352/2890: d:\projectData\ScopusData2018-2023\2023\202300351
#
# ===== Processing file 353/2890: d:\projectData\ScopusData2018-2023\2023\202300352
#
# ===== Processing file 354/2890: d:\projectData\ScopusData2018-2023\2023\202300353
#
# ===== Processing file 355/2890: d:\projectData\ScopusData2018-2023\2023\202300354
#
# ===== Processing file 356/2890: d:\projectData\ScopusData2018-2023\2023\202300355
#
# ===== Processing file 357/2890: d:\projectData\ScopusData2018-2023\2023\202300356
#
# ===== Processing file 358/2890: d:\projectData\ScopusData2018-2023\2023\202300357
#
# ===== Processing file 359/2890: d:\projectData\ScopusData2018-2023\2023\202300358
#
# ===== Processing file 360/2890: d:\projectData\ScopusData2018-2023\2023\202300359
#
# ===== Processing file 361/2890: d:\projectData\ScopusData2018-2023\2023\202300360
#
# ===== Processing file 362/2890: d:\projectData\ScopusData2018-2023\2023\202300361
#
# ===== Processing file 363/2890: d:\projectData\ScopusData2018-2023\2023\202300362
#
# ===== Processing file 364/2890: d:\projectData\ScopusData2018-2023\2023\202300363
#
# ===== Processing file 365/2890: d:\projectData\ScopusData2018-2023\2023\202300364
#
# ===== Processing file 366/2890: d:\projectData\ScopusData2018-2023\2023\202300365
#
# ===== Processing file 367/2890: d:\projectData\ScopusData2018-2023\2023\202300366
#
# ===== Processing file 368/2890: d:\projectData\ScopusData2018-2023\2023\202300367
#
# ===== Processing file 369/2890: d:\projectData\ScopusData2018-2023\2023\202300368
#
# ===== Processing file 370/2890: d:\projectData\ScopusData2018-2023\2023\202300369
#
# ===== Processing file 371/2890: d:\projectData\ScopusData2018-2023\2023\202300370
#
# ===== Processing file 372/2890: d:\projectData\ScopusData2018-2023\2023\202300371
#
# ===== Processing file 373/2890: d:\projectData\ScopusData2018-2023\2023\202300372
#
# ===== Processing file 374/2890: d:\projectData\ScopusData2018-2023\2023\202300373
#
# ===== Processing file 375/2890: d:\projectData\ScopusData2018-2023\2023\202300374
#
# ===== Processing file 376/2890: d:\projectData\ScopusData2018-2023\2023\202300375
#
# ===== Processing file 377/2890: d:\projectData\ScopusData2018-2023\2023\202300376
#
# ===== Processing file 378/2890: d:\projectData\ScopusData2018-2023\2023\202300377
#
# ===== Processing file 379/2890: d:\projectData\ScopusData2018-2023\2023\202300378
#
# ===== Processing file 380/2890: d:\projectData\ScopusData2018-2023\2023\202300379
#
# ===== Processing file 381/2890: d:\projectData\ScopusData2018-2023\2023\202300380
#
# ===== Processing file 382/2890: d:\projectData\ScopusData2018-2023\2023\202300381
#
# ===== Processing file 383/2890: d:\projectData\ScopusData2018-2023\2023\202300382
#
# ===== Processing file 384/2890: d:\projectData\ScopusData2018-2023\2023\202300383
#
# ===== Processing file 385/2890: d:\projectData\ScopusData2018-2023\2023\202300384
#
# ===== Processing file 386/2890: d:\projectData\ScopusData2018-2023\2023\202300385
#
# ===== Processing file 387/2890: d:\projectData\ScopusData2018-2023\2023\202300386
#
# ===== Processing file 388/2890: d:\projectData\ScopusData2018-2023\2023\202300387
#
# ===== Processing file 389/2890: d:\projectData\ScopusData2018-2023\2023\202300388
#
# ===== Processing file 390/2890: d:\projectData\ScopusData2018-2023\2023\202300389
#
# ===== Processing file 391/2890: d:\projectData\ScopusData2018-2023\2023\202300390
#
# ===== Processing file 392/2890: d:\projectData\ScopusData2018-2023\2023\202300391
#
# ===== Processing file 393/2890: d:\projectData\ScopusData2018-2023\2023\202300392
#
# ===== Processing file 394/2890: d:\projectData\ScopusData2018-2023\2023\202300393
#
# ===== Processing file 395/2890: d:\projectData\ScopusData2018-2023\2023\202300394
#
# ===== Processing file 396/2890: d:\projectData\ScopusData2018-2023\2023\202300395
#
# ===== Processing file 397/2890: d:\projectData\ScopusData2018-2023\2023\202300396
#
# ===== Processing file 398/2890: d:\projectData\ScopusData2018-2023\2023\202300397
#
# ===== Processing file 399/2890: d:\projectData\ScopusData2018-2023\2023\202300398
#
# ===== Processing file 400/2890: d:\projectData\ScopusData2018-2023\2023\202300399
#
# ===== Processing file 401/2890: d:\projectData\ScopusData2018-2023\2023\202300400
#
# ===== Processing file 402/2890: d:\projectData\ScopusData2018-2023\2023\202300401
#
# ===== Processing file 403/2890: d:\projectData\ScopusData2018-2023\2023\202300402
#
# ===== Processing file 404/2890: d:\projectData\ScopusData2018-2023\2023\202300403
#
# ===== Processing file 405/2890: d:\projectData\ScopusData2018-2023\2023\202300404
#
# ===== Processing file 406/2890: d:\projectData\ScopusData2018-2023\2023\202300405
#
# ===== Processing file 407/2890: d:\projectData\ScopusData2018-2023\2023\202300406
#
# ===== Processing file 408/2890: d:\projectData\ScopusData2018-2023\2023\202300407
#
# ===== Processing file 409/2890: d:\projectData\ScopusData2018-2023\2023\202300408
#
# ===== Processing file 410/2890: d:\projectData\ScopusData2018-2023\2023\202300409
#
# ===== Processing file 411/2890: d:\projectData\ScopusData2018-2023\2023\202300410
#
# ===== Processing file 412/2890: d:\projectData\ScopusData2018-2023\2023\202300411
#
# ===== Processing file 413/2890: d:\projectData\ScopusData2018-2023\2023\202300412
#
# ===== Processing file 414/2890: d:\projectData\ScopusData2018-2023\2023\202300413
#
# ===== Processing file 415/2890: d:\projectData\ScopusData2018-2023\2023\202300414
#
# ===== Processing file 416/2890: d:\projectData\ScopusData2018-2023\2023\202300415
#
# ===== Processing file 417/2890: d:\projectData\ScopusData2018-2023\2023\202300416
#
# ===== Processing file 418/2890: d:\projectData\ScopusData2018-2023\2023\202300417
#
# ===== Processing file 419/2890: d:\projectData\ScopusData2018-2023\2023\202300418
#
# ===== Processing file 420/2890: d:\projectData\ScopusData2018-2023\2023\202300419
#
# ===== Processing file 421/2890: d:\projectData\ScopusData2018-2023\2023\202300420
#
# ===== Processing file 422/2890: d:\projectData\ScopusData2018-2023\2023\202300421
#
# ===== Processing file 423/2890: d:\projectData\ScopusData2018-2023\2023\202300422
#
# ===== Processing file 424/2890: d:\projectData\ScopusData2018-2023\2023\202300423
#
# ===== Processing file 425/2890: d:\projectData\ScopusData2018-2023\2023\202300424
#
# ===== Processing file 426/2890: d:\projectData\ScopusData2018-2023\2023\202300425
#
# ===== Processing file 427/2890: d:\projectData\ScopusData2018-2023\2023\202300426
#
# ===== Processing file 428/2890: d:\projectData\ScopusData2018-2023\2023\202300427
#
# ===== Processing file 429/2890: d:\projectData\ScopusData2018-2023\2023\202300428
#
# ===== Processing file 430/2890: d:\projectData\ScopusData2018-2023\2023\202300429
#
# ===== Processing file 431/2890: d:\projectData\ScopusData2018-2023\2023\202300430
#
# ===== Processing file 432/2890: d:\projectData\ScopusData2018-2023\2023\202300431
#
# ===== Processing file 433/2890: d:\projectData\ScopusData2018-2023\2023\202300432
#
# ===== Processing file 434/2890: d:\projectData\ScopusData2018-2023\2023\202300433
#
# ===== Processing file 435/2890: d:\projectData\ScopusData2018-2023\2023\202300434
#
# ===== Processing file 436/2890: d:\projectData\ScopusData2018-2023\2023\202300435
#
# ===== Processing file 437/2890: d:\projectData\ScopusData2018-2023\2023\202300436
#
# ===== Processing file 438/2890: d:\projectData\ScopusData2018-2023\2023\202300437
#
# ===== Processing file 439/2890: d:\projectData\ScopusData2018-2023\2023\202300438
#
# ===== Processing file 440/2890: d:\projectData\ScopusData2018-2023\2023\202300439
#
# ===== Processing file 441/2890: d:\projectData\ScopusData2018-2023\2023\202300440
#
# ===== Processing file 442/2890: d:\projectData\ScopusData2018-2023\2023\202300441
#
# ===== Processing file 443/2890: d:\projectData\ScopusData2018-2023\2023\202300442
#
# ===== Processing file 444/2890: d:\projectData\ScopusData2018-2023\2023\202300443
#
# ===== Processing file 445/2890: d:\projectData\ScopusData2018-2023\2023\202300444
#
# ===== Processing file 446/2890: d:\projectData\ScopusData2018-2023\2023\202300445
#
# ===== Processing file 447/2890: d:\projectData\ScopusData2018-2023\2023\202300446
#
# ===== Processing file 448/2890: d:\projectData\ScopusData2018-2023\2023\202300447
#
# ===== Processing file 449/2890: d:\projectData\ScopusData2018-2023\2023\202300448
#
# ===== Processing file 450/2890: d:\projectData\ScopusData2018-2023\2023\202300449
#
# ===== Processing file 451/2890: d:\projectData\ScopusData2018-2023\2023\202300450
#
# ===== Processing file 452/2890: d:\projectData\ScopusData2018-2023\2023\202300451
#
# ===== Processing file 453/2890: d:\projectData\ScopusData2018-2023\2023\202300452
#
# ===== Processing file 454/2890: d:\projectData\ScopusData2018-2023\2023\202300453
#
# ===== Processing file 455/2890: d:\projectData\ScopusData2018-2023\2023\202300454
#
# ===== Processing file 456/2890: d:\projectData\ScopusData2018-2023\2023\202300455
#
# ===== Processing file 457/2890: d:\projectData\ScopusData2018-2023\2023\202300456
#
# ===== Processing file 458/2890: d:\projectData\ScopusData2018-2023\2023\202300457
#
# ===== Processing file 459/2890: d:\projectData\ScopusData2018-2023\2023\202300458
#
# ===== Processing file 460/2890: d:\projectData\ScopusData2018-2023\2023\202300459
#
# ===== Processing file 461/2890: d:\projectData\ScopusData2018-2023\2023\202300460
#
# ===== Processing file 462/2890: d:\projectData\ScopusData2018-2023\2023\202300461
#
# ===== Processing file 463/2890: d:\projectData\ScopusData2018-2023\2023\202300462
#
# ===== Processing file 464/2890: d:\projectData\ScopusData2018-2023\2023\202300463
#
# ===== Processing file 465/2890: d:\projectData\ScopusData2018-2023\2023\202300464
#
# ===== Processing file 466/2890: d:\projectData\ScopusData2018-2023\2023\202300465
#
# ===== Processing file 467/2890: d:\projectData\ScopusData2018-2023\2023\202300466
#
# ===== Processing file 468/2890: d:\projectData\ScopusData2018-2023\2023\202300467
#
# ===== Processing file 469/2890: d:\projectData\ScopusData2018-2023\2023\202300468
#
# ===== Processing file 470/2890: d:\projectData\ScopusData2018-2023\2023\202300469
#
# ===== Processing file 471/2890: d:\projectData\ScopusData2018-2023\2023\202300470
#
# ===== Processing file 472/2890: d:\projectData\ScopusData2018-2023\2023\202300471
#
# ===== Processing file 473/2890: d:\projectData\ScopusData2018-2023\2023\202300472
#
# ===== Processing file 474/2890: d:\projectData\ScopusData2018-2023\2023\202300473
#
# ===== Processing file 475/2890: d:\projectData\ScopusData2018-2023\2023\202300474
#
# ===== Processing file 476/2890: d:\projectData\ScopusData2018-2023\2023\202300475
#
# ===== Processing file 477/2890: d:\projectData\ScopusData2018-2023\2023\202300476
#
# ===== Processing file 478/2890: d:\projectData\ScopusData2018-2023\2023\202300477
#
# ===== Processing file 479/2890: d:\projectData\ScopusData2018-2023\2023\202300478
#
# ===== Processing file 480/2890: d:\projectData\ScopusData2018-2023\2023\202300479
#
# ===== Processing file 481/2890: d:\projectData\ScopusData2018-2023\2023\202300480
#
# ===== Processing file 482/2890: d:\projectData\ScopusData2018-2023\2023\202300481
#
# ===== Processing file 483/2890: d:\projectData\ScopusData2018-2023\2023\202300482
#
# ===== Processing file 484/2890: d:\projectData\ScopusData2018-2023\2023\202300483
#
# ===== Processing file 485/2890: d:\projectData\ScopusData2018-2023\2023\202300484
#
# ===== Processing file 486/2890: d:\projectData\ScopusData2018-2023\2023\202300485
#
# ===== Processing file 487/2890: d:\projectData\ScopusData2018-2023\2023\202300486
#
# ===== Processing file 488/2890: d:\projectData\ScopusData2018-2023\2023\202300487
#
# ===== Processing file 489/2890: d:\projectData\ScopusData2018-2023\2023\202300488
#
# ===== Processing file 490/2890: d:\projectData\ScopusData2018-2023\2023\202300489
#
# ===== Processing file 491/2890: d:\projectData\ScopusData2018-2023\2023\202300490
#
# ===== Processing file 492/2890: d:\projectData\ScopusData2018-2023\2023\202300491
#
# ===== Processing file 493/2890: d:\projectData\ScopusData2018-2023\2023\202300492
#
# ===== Processing file 494/2890: d:\projectData\ScopusData2018-2023\2023\202300493
#
# ===== Processing file 495/2890: d:\projectData\ScopusData2018-2023\2023\202300494
#
# ===== Processing file 496/2890: d:\projectData\ScopusData2018-2023\2023\202300495
#
# ===== Processing file 497/2890: d:\projectData\ScopusData2018-2023\2023\202300496
#
# ===== Processing file 498/2890: d:\projectData\ScopusData2018-2023\2023\202300497
#
# ===== Processing file 499/2890: d:\projectData\ScopusData2018-2023\2023\202300498
#
# ===== Processing file 500/2890: d:\projectData\ScopusData2018-2023\2023\202300499
#
# ===== Processing file 501/2890: d:\projectData\ScopusData2018-2023\2023\202300500
#
# ===== Processing file 502/2890: d:\projectData\ScopusData2018-2023\2023\202300501
#
# ===== Processing file 503/2890: d:\projectData\ScopusData2018-2023\2023\202300502
#
# ===== Processing file 504/2890: d:\projectData\ScopusData2018-2023\2023\202300503
#
# ===== Processing file 505/2890: d:\projectData\ScopusData2018-2023\2023\202300504
#
# ===== Processing file 506/2890: d:\projectData\ScopusData2018-2023\2023\202300505
#
# ===== Processing file 507/2890: d:\projectData\ScopusData2018-2023\2023\202300506
#
# ===== Processing file 508/2890: d:\projectData\ScopusData2018-2023\2023\202300507
#
# ===== Processing file 509/2890: d:\projectData\ScopusData2018-2023\2023\202300508
#
# ===== Processing file 510/2890: d:\projectData\ScopusData2018-2023\2023\202300509
#
# ===== Processing file 511/2890: d:\projectData\ScopusData2018-2023\2023\202300510
#
# ===== Processing file 512/2890: d:\projectData\ScopusData2018-2023\2023\202300511
#
# ===== Processing file 513/2890: d:\projectData\ScopusData2018-2023\2023\202300512
#
# ===== Processing file 514/2890: d:\projectData\ScopusData2018-2023\2023\202300513
#
# ===== Processing file 515/2890: d:\projectData\ScopusData2018-2023\2023\202300514
#
# ===== Processing file 516/2890: d:\projectData\ScopusData2018-2023\2023\202300515
#
# ===== Processing file 517/2890: d:\projectData\ScopusData2018-2023\2023\202300516
#
# ===== Processing file 518/2890: d:\projectData\ScopusData2018-2023\2023\202300517
#
# ===== Processing file 519/2890: d:\projectData\ScopusData2018-2023\2023\202300518
#
# ===== Processing file 520/2890: d:\projectData\ScopusData2018-2023\2023\202300519
#
# ===== Processing file 521/2890: d:\projectData\ScopusData2018-2023\2023\202300520
#
# ===== Processing file 522/2890: d:\projectData\ScopusData2018-2023\2023\202300521
#
# ===== Processing file 523/2890: d:\projectData\ScopusData2018-2023\2023\202300522
#
# ===== Processing file 524/2890: d:\projectData\ScopusData2018-2023\2023\202300523
#
# ===== Processing file 525/2890: d:\projectData\ScopusData2018-2023\2023\202300524
#
# ===== Processing file 526/2890: d:\projectData\ScopusData2018-2023\2023\202300525
#
# ===== Processing file 527/2890: d:\projectData\ScopusData2018-2023\2023\202300526
#
# ===== Processing file 528/2890: d:\projectData\ScopusData2018-2023\2023\202300527
#
# ===== Processing file 529/2890: d:\projectData\ScopusData2018-2023\2023\202300528
#
# ===== Processing file 530/2890: d:\projectData\ScopusData2018-2023\2023\202300529
#
# ===== Processing file 531/2890: d:\projectData\ScopusData2018-2023\2023\202300530
#
# ===== Processing file 532/2890: d:\projectData\ScopusData2018-2023\2023\202300531
#
# ===== Processing file 533/2890: d:\projectData\ScopusData2018-2023\2023\202300532
#
# ===== Processing file 534/2890: d:\projectData\ScopusData2018-2023\2023\202300533
#
# ===== Processing file 535/2890: d:\projectData\ScopusData2018-2023\2023\202300534
#
# ===== Processing file 536/2890: d:\projectData\ScopusData2018-2023\2023\202300535
#
# ===== Processing file 537/2890: d:\projectData\ScopusData2018-2023\2023\202300536
#
# ===== Processing file 538/2890: d:\projectData\ScopusData2018-2023\2023\202300537
#
# ===== Processing file 539/2890: d:\projectData\ScopusData2018-2023\2023\202300538
#
# ===== Processing file 540/2890: d:\projectData\ScopusData2018-2023\2023\202300539
#
# ===== Processing file 541/2890: d:\projectData\ScopusData2018-2023\2023\202300540
#
# ===== Processing file 542/2890: d:\projectData\ScopusData2018-2023\2023\202300541
#
# ===== Processing file 543/2890: d:\projectData\ScopusData2018-2023\2023\202300542
#
# ===== Processing file 544/2890: d:\projectData\ScopusData2018-2023\2023\202300543
#
# ===== Processing file 545/2890: d:\projectData\ScopusData2018-2023\2023\202300544
#
# ===== Processing file 546/2890: d:\projectData\ScopusData2018-2023\2023\202300545
#
# ===== Processing file 547/2890: d:\projectData\ScopusData2018-2023\2023\202300546
#
# ===== Processing file 548/2890: d:\projectData\ScopusData2018-2023\2023\202300547
#
# ===== Processing file 549/2890: d:\projectData\ScopusData2018-2023\2023\202300548
#
# ===== Processing file 550/2890: d:\projectData\ScopusData2018-2023\2023\202300549
#
# ===== Processing file 551/2890: d:\projectData\ScopusData2018-2023\2023\202300550
#
# ===== Processing file 552/2890: d:\projectData\ScopusData2018-2023\2023\202300551
#
# ===== Processing file 553/2890: d:\projectData\ScopusData2018-2023\2023\202300552
#
# ===== Processing file 554/2890: d:\projectData\ScopusData2018-2023\2023\202300553
#
# ===== Processing file 555/2890: d:\projectData\ScopusData2018-2023\2023\202300554
#
# ===== Processing file 556/2890: d:\projectData\ScopusData2018-2023\2023\202300555
#
# ===== Processing file 557/2890: d:\projectData\ScopusData2018-2023\2023\202300556
#
# ===== Processing file 558/2890: d:\projectData\ScopusData2018-2023\2023\202300557
#
# ===== Processing file 559/2890: d:\projectData\ScopusData2018-2023\2023\202300558
#
# ===== Processing file 560/2890: d:\projectData\ScopusData2018-2023\2023\202300559
#
# ===== Processing file 561/2890: d:\projectData\ScopusData2018-2023\2023\202300560
#
# ===== Processing file 562/2890: d:\projectData\ScopusData2018-2023\2023\202300561
#
# ===== Processing file 563/2890: d:\projectData\ScopusData2018-2023\2023\202300562
#
# ===== Processing file 564/2890: d:\projectData\ScopusData2018-2023\2023\202300563
#
# ===== Processing file 565/2890: d:\projectData\ScopusData2018-2023\2023\202300564
#
# ===== Processing file 566/2890: d:\projectData\ScopusData2018-2023\2023\202300565
#
# ===== Processing file 567/2890: d:\projectData\ScopusData2018-2023\2023\202300566
#
# ===== Processing file 568/2890: d:\projectData\ScopusData2018-2023\2023\202300567
#
# ===== Processing file 569/2890: d:\projectData\ScopusData2018-2023\2023\202300568
#
# ===== Processing file 570/2890: d:\projectData\ScopusData2018-2023\2023\202300569
#
# ===== Processing file 571/2890: d:\projectData\ScopusData2018-2023\2023\202300570
#
# ===== Processing file 572/2890: d:\projectData\ScopusData2018-2023\2023\202300571
#
# ===== Processing file 573/2890: d:\projectData\ScopusData2018-2023\2023\202300572
#
# ===== Processing file 574/2890: d:\projectData\ScopusData2018-2023\2023\202300573
#
# ===== Processing file 575/2890: d:\projectData\ScopusData2018-2023\2023\202300574
#
# ===== Processing file 576/2890: d:\projectData\ScopusData2018-2023\2023\202300575
#
# ===== Processing file 577/2890: d:\projectData\ScopusData2018-2023\2023\202300576
#
# ===== Processing file 578/2890: d:\projectData\ScopusData2018-2023\2023\202300577
#
# ===== Processing file 579/2890: d:\projectData\ScopusData2018-2023\2023\202300578
#
# ...
#
# ===== Processing file 2702/2890: d:\projectData\ScopusData2018-2023\2023\202302701
#
# ===== Processing file 2703/2890: d:\projectData\ScopusData2018-2023\2023\202302702
#
# ===== Processing file 2704/2890: d:\projectData\ScopusData2018-2023\2023\202302703
#
# ===== Processing file 2705/2890: d:\projectData\ScopusData2018-2023\2023\202302704
#
# ===== Processing file 2706/2890: d:\projectData\ScopusData2018-2023\2023\202302705
#
# ===== Processing file 2707/2890: d:\projectData\ScopusData2018-2023\2023\202302706
#
# ===== Processing file 2708/2890: d:\projectData\ScopusData2018-2023\2023\202302707
#
# ===== Processing file 2709/2890: d:\projectData\ScopusData2018-2023\2023\202302708
#
# ===== Processing file 2710/2890: d:\projectData\ScopusData2018-2023\2023\202302709
#
# ===== Processing file 2711/2890: d:\projectData\ScopusData2018-2023\2023\202302710
#
# ===== Processing file 2712/2890: d:\projectData\ScopusData2018-2023\2023\202302711
#
# ===== Processing file 2713/2890: d:\projectData\ScopusData2018-2023\2023\202302712
#
# ===== Processing file 2714/2890: d:\projectData\ScopusData2018-2023\2023\202302713
#
# ===== Processing file 2715/2890: d:\projectData\ScopusData2018-2023\2023\202302714
#
# ===== Processing file 2716/2890: d:\projectData\ScopusData2018-2023\2023\202302715
#
# ===== Processing file 2717/2890: d:\projectData\ScopusData2018-2023\2023\202302716
#
# ===== Processing file 2718/2890: d:\projectData\ScopusData2018-2023\2023\202302717
#
# ===== Processing file 2719/2890: d:\projectData\ScopusData2018-2023\2023\202302718
#
# ===== Processing file 2720/2890: d:\projectData\ScopusData2018-2023\2023\202302719
#
# ===== Processing file 2721/2890: d:\projectData\ScopusData2018-2023\2023\202302720
#
# ===== Processing file 2722/2890: d:\projectData\ScopusData2018-2023\2023\202302721
#
# ===== Processing file 2723/2890: d:\projectData\ScopusData2018-2023\2023\202302722
#
# ===== Processing file 2724/2890: d:\projectData\ScopusData2018-2023\2023\202302723
#
# ===== Processing file 2725/2890: d:\projectData\ScopusData2018-2023\2023\202302724
#
# ===== Processing file 2726/2890: d:\projectData\ScopusData2018-2023\2023\202302725
#
# ===== Processing file 2727/2890: d:\projectData\ScopusData2018-2023\2023\202302726
#
# ===== Processing file 2728/2890: d:\projectData\ScopusData2018-2023\2023\202302727
#
# ===== Processing file 2729/2890: d:\projectData\ScopusData2018-2023\2023\202302728
#
# ===== Processing file 2730/2890: d:\projectData\ScopusData2018-2023\2023\202302729
#
# ===== Processing file 2731/2890: d:\projectData\ScopusData2018-2023\2023\202302730
#
# ===== Processing file 2732/2890: d:\projectData\ScopusData2018-2023\2023\202302731
#
# ===== Processing file 2733/2890: d:\projectData\ScopusData2018-2023\2023\202302732
#
# ===== Processing file 2734/2890: d:\projectData\ScopusData2018-2023\2023\202302733
#
# ===== Processing file 2735/2890: d:\projectData\ScopusData2018-2023\2023\202302734
#
# ===== Processing file 2736/2890: d:\projectData\ScopusData2018-2023\2023\202302735
#
# ===== Processing file 2737/2890: d:\projectData\ScopusData2018-2023\2023\202302736
#
# ===== Processing file 2738/2890: d:\projectData\ScopusData2018-2023\2023\202302737
#
# ===== Processing file 2739/2890: d:\projectData\ScopusData2018-2023\2023\202302738
#
# ===== Processing file 2740/2890: d:\projectData\ScopusData2018-2023\2023\202302739
#
# ===== Processing file 2741/2890: d:\projectData\ScopusData2018-2023\2023\202302740
#
# ===== Processing file 2742/2890: d:\projectData\ScopusData2018-2023\2023\202302741
#
# ===== Processing file 2743/2890: d:\projectData\ScopusData2018-2023\2023\202302742
#
# ===== Processing file 2744/2890: d:\projectData\ScopusData2018-2023\2023\202302743
#
# ===== Processing file 2745/2890: d:\projectData\ScopusData2018-2023\2023\202302744
#
# ===== Processing file 2746/2890: d:\projectData\ScopusData2018-2023\2023\202302745
#
# ===== Processing file 2747/2890: d:\projectData\ScopusData2018-2023\2023\202302746
#
# ===== Processing file 2748/2890: d:\projectData\ScopusData2018-2023\2023\202302747
#
# ===== Processing file 2749/2890: d:\projectData\ScopusData2018-2023\2023\202302748
#
# ===== Processing file 2750/2890: d:\projectData\ScopusData2018-2023\2023\202302749
#
# ===== Processing file 2751/2890: d:\projectData\ScopusData2018-2023\2023\202302750
#
# ===== Processing file 2752/2890: d:\projectData\ScopusData2018-2023\2023\202302751
#
# ===== Processing file 2753/2890: d:\projectData\ScopusData2018-2023\2023\202302752
#
# ===== Processing file 2754/2890: d:\projectData\ScopusData2018-2023\2023\202302753
#
# ===== Processing file 2755/2890: d:\projectData\ScopusData2018-2023\2023\202302754
#
# ===== Processing file 2756/2890: d:\projectData\ScopusData2018-2023\2023\202302755
#
# ===== Processing file 2757/2890: d:\projectData\ScopusData2018-2023\2023\202302756
#
# ===== Processing file 2758/2890: d:\projectData\ScopusData2018-2023\2023\202302757
#
# ===== Processing file 2759/2890: d:\projectData\ScopusData2018-2023\2023\202302758
#
# ===== Processing file 2760/2890: d:\projectData\ScopusData2018-2023\2023\202302759
#
# ===== Processing file 2761/2890: d:\projectData\ScopusData2018-2023\2023\202302760
#
# ===== Processing file 2762/2890: d:\projectData\ScopusData2018-2023\2023\202302761
#
# ===== Processing file 2763/2890: d:\projectData\ScopusData2018-2023\2023\202302762
#
# ===== Processing file 2764/2890: d:\projectData\ScopusData2018-2023\2023\202302763
#
# ===== Processing file 2765/2890: d:\projectData\ScopusData2018-2023\2023\202302764
#
# ===== Processing file 2766/2890: d:\projectData\ScopusData2018-2023\2023\202302765
#
# ===== Processing file 2767/2890: d:\projectData\ScopusData2018-2023\2023\202302766
#
# ===== Processing file 2768/2890: d:\projectData\ScopusData2018-2023\2023\202302767
#
# ===== Processing file 2769/2890: d:\projectData\ScopusData2018-2023\2023\202302768
#
# ===== Processing file 2770/2890: d:\projectData\ScopusData2018-2023\2023\202302769
#
# ===== Processing file 2771/2890: d:\projectData\ScopusData2018-2023\2023\202302770
#
# ===== Processing file 2772/2890: d:\projectData\ScopusData2018-2023\2023\202302771
#
# ===== Processing file 2773/2890: d:\projectData\ScopusData2018-2023\2023\202302772
#
# ===== Processing file 2774/2890: d:\projectData\ScopusData2018-2023\2023\202302773
#
# ===== Processing file 2775/2890: d:\projectData\ScopusData2018-2023\2023\202302774
#
# ===== Processing file 2776/2890: d:\projectData\ScopusData2018-2023\2023\202302775
#
# ===== Processing file 2777/2890: d:\projectData\ScopusData2018-2023\2023\202302776
#
# ===== Processing file 2778/2890: d:\projectData\ScopusData2018-2023\2023\202302777
#
# ===== Processing file 2779/2890: d:\projectData\ScopusData2018-2023\2023\202302778
#
# ===== Processing file 2780/2890: d:\projectData\ScopusData2018-2023\2023\202302779
#
# ===== Processing file 2781/2890: d:\projectData\ScopusData2018-2023\2023\202302780
#
# ===== Processing file 2782/2890: d:\projectData\ScopusData2018-2023\2023\202302781
#
# ===== Processing file 2783/2890: d:\projectData\ScopusData2018-2023\2023\202302782
#
# ===== Processing file 2784/2890: d:\projectData\ScopusData2018-2023\2023\202302783
#
# ===== Processing file 2785/2890: d:\projectData\ScopusData2018-2023\2023\202302784
#
# ===== Processing file 2786/2890: d:\projectData\ScopusData2018-2023\2023\202302785
#
# ===== Processing file 2787/2890: d:\projectData\ScopusData2018-2023\2023\202302786
#
# ===== Processing file 2788/2890: d:\projectData\ScopusData2018-2023\2023\202302787
#
# ===== Processing file 2789/2890: d:\projectData\ScopusData2018-2023\2023\202302788
#
# ===== Processing file 2790/2890: d:\projectData\ScopusData2018-2023\2023\202302789
#
# ===== Processing file 2791/2890: d:\projectData\ScopusData2018-2023\2023\202302790
#
# ===== Processing file 2792/2890: d:\projectData\ScopusData2018-2023\2023\202302791
#
# ===== Processing file 2793/2890: d:\projectData\ScopusData2018-2023\2023\202302792
#
# ===== Processing file 2794/2890: d:\projectData\ScopusData2018-2023\2023\202302793
#
# ===== Processing file 2795/2890: d:\projectData\ScopusData2018-2023\2023\202302794
#
# ===== Processing file 2796/2890: d:\projectData\ScopusData2018-2023\2023\202302795
#
# ===== Processing file 2797/2890: d:\projectData\ScopusData2018-2023\2023\202302796
#
# ===== Processing file 2798/2890: d:\projectData\ScopusData2018-2023\2023\202302797
#
# ===== Processing file 2799/2890: d:\projectData\ScopusData2018-2023\2023\202302798
#
# ===== Processing file 2800/2890: d:\projectData\ScopusData2018-2023\2023\202302799
#
# ===== Processing file 2801/2890: d:\projectData\ScopusData2018-2023\2023\202302800
#
# ===== Processing file 2802/2890: d:\projectData\ScopusData2018-2023\2023\202302801
#
# ===== Processing file 2803/2890: d:\projectData\ScopusData2018-2023\2023\202302802
#
# ===== Processing file 2804/2890: d:\projectData\ScopusData2018-2023\2023\202302803
#
# ===== Processing file 2805/2890: d:\projectData\ScopusData2018-2023\2023\202302804
#
# ===== Processing file 2806/2890: d:\projectData\ScopusData2018-2023\2023\202302805
#
# ===== Processing file 2807/2890: d:\projectData\ScopusData2018-2023\2023\202302806
#
# ===== Processing file 2808/2890: d:\projectData\ScopusData2018-2023\2023\202302807
#
# ===== Processing file 2809/2890: d:\projectData\ScopusData2018-2023\2023\202302808
#
# ===== Processing file 2810/2890: d:\projectData\ScopusData2018-2023\2023\202302809
#
# ===== Processing file 2811/2890: d:\projectData\ScopusData2018-2023\2023\202302810
#
# ===== Processing file 2812/2890: d:\projectData\ScopusData2018-2023\2023\202302811
#
# ===== Processing file 2813/2890: d:\projectData\ScopusData2018-2023\2023\202302812
#
# ===== Processing file 2814/2890: d:\projectData\ScopusData2018-2023\2023\202302813
#
# ===== Processing file 2815/2890: d:\projectData\ScopusData2018-2023\2023\202302814
#
# ===== Processing file 2816/2890: d:\projectData\ScopusData2018-2023\2023\202302815
#
# ===== Processing file 2817/2890: d:\projectData\ScopusData2018-2023\2023\202302816
#
# ===== Processing file 2818/2890: d:\projectData\ScopusData2018-2023\2023\202302817
#
# ===== Processing file 2819/2890: d:\projectData\ScopusData2018-2023\2023\202302818
#
# ===== Processing file 2820/2890: d:\projectData\ScopusData2018-2023\2023\202302819
#
# ===== Processing file 2821/2890: d:\projectData\ScopusData2018-2023\2023\202302820
#
# ===== Processing file 2822/2890: d:\projectData\ScopusData2018-2023\2023\202302821
#
# ===== Processing file 2823/2890: d:\projectData\ScopusData2018-2023\2023\202302822
#
# ===== Processing file 2824/2890: d:\projectData\ScopusData2018-2023\2023\202302823
#
# ===== Processing file 2825/2890: d:\projectData\ScopusData2018-2023\2023\202302824
#
# ===== Processing file 2826/2890: d:\projectData\ScopusData2018-2023\2023\202302825
#
# ===== Processing file 2827/2890: d:\projectData\ScopusData2018-2023\2023\202302826
#
# ===== Processing file 2828/2890: d:\projectData\ScopusData2018-2023\2023\202302827
#
# ===== Processing file 2829/2890: d:\projectData\ScopusData2018-2023\2023\202302828
#
# ===== Processing file 2830/2890: d:\projectData\ScopusData2018-2023\2023\202302829
#
# ===== Processing file 2831/2890: d:\projectData\ScopusData2018-2023\2023\202302830
#
# ===== Processing file 2832/2890: d:\projectData\ScopusData2018-2023\2023\202302831
#
# ===== Processing file 2833/2890: d:\projectData\ScopusData2018-2023\2023\202302832
#
# ===== Processing file 2834/2890: d:\projectData\ScopusData2018-2023\2023\202302833
#
# ===== Processing file 2835/2890: d:\projectData\ScopusData2018-2023\2023\202302834
#
# ===== Processing file 2836/2890: d:\projectData\ScopusData2018-2023\2023\202302835
#
# ===== Processing file 2837/2890: d:\projectData\ScopusData2018-2023\2023\202302836
#
# ===== Processing file 2838/2890: d:\projectData\ScopusData2018-2023\2023\202302837
#
# ===== Processing file 2839/2890: d:\projectData\ScopusData2018-2023\2023\202302838
#
# ===== Processing file 2840/2890: d:\projectData\ScopusData2018-2023\2023\202302839
#
# ===== Processing file 2841/2890: d:\projectData\ScopusData2018-2023\2023\202302840
#
# ===== Processing file 2842/2890: d:\projectData\ScopusData2018-2023\2023\202302841
#
# ===== Processing file 2843/2890: d:\projectData\ScopusData2018-2023\2023\202302842
#
# ===== Processing file 2844/2890: d:\projectData\ScopusData2018-2023\2023\202302843
#
# ===== Processing file 2845/2890: d:\projectData\ScopusData2018-2023\2023\202302844
#
# ===== Processing file 2846/2890: d:\projectData\ScopusData2018-2023\2023\202302845
#
# ===== Processing file 2847/2890: d:\projectData\ScopusData2018-2023\2023\202302846
#
# ===== Processing file 2848/2890: d:\projectData\ScopusData2018-2023\2023\202302847
#
# ===== Processing file 2849/2890: d:\projectData\ScopusData2018-2023\2023\202302848
#
# ===== Processing file 2850/2890: d:\projectData\ScopusData2018-2023\2023\202302849
#
# ===== Processing file 2851/2890: d:\projectData\ScopusData2018-2023\2023\202302850
#
# ===== Processing file 2852/2890: d:\projectData\ScopusData2018-2023\2023\202302851
#
# ===== Processing file 2853/2890: d:\projectData\ScopusData2018-2023\2023\202302852
#
# ===== Processing file 2854/2890: d:\projectData\ScopusData2018-2023\2023\202302853
#
# ===== Processing file 2855/2890: d:\projectData\ScopusData2018-2023\2023\202302854
#
# ===== Processing file 2856/2890: d:\projectData\ScopusData2018-2023\2023\202302855
#
# ===== Processing file 2857/2890: d:\projectData\ScopusData2018-2023\2023\202302856
#
# ===== Processing file 2858/2890: d:\projectData\ScopusData2018-2023\2023\202302857
#
# ===== Processing file 2859/2890: d:\projectData\ScopusData2018-2023\2023\202302858
#
# ===== Processing file 2860/2890: d:\projectData\ScopusData2018-2023\2023\202302859
#
# ===== Processing file 2861/2890: d:\projectData\ScopusData2018-2023\2023\202302860
#
# ===== Processing file 2862/2890: d:\projectData\ScopusData2018-2023\2023\202302861
#
# ===== Processing file 2863/2890: d:\projectData\ScopusData2018-2023\2023\202302862
#
# ===== Processing file 2864/2890: d:\projectData\ScopusData2018-2023\2023\202302863
#
# ===== Processing file 2865/2890: d:\projectData\ScopusData2018-2023\2023\202302864
#
# ===== Processing file 2866/2890: d:\projectData\ScopusData2018-2023\2023\202302865
#
# ===== Processing file 2867/2890: d:\projectData\ScopusData2018-2023\2023\202302866
#
# ===== Processing file 2868/2890: d:\projectData\ScopusData2018-2023\2023\202302867
#
# ===== Processing file 2869/2890: d:\projectData\ScopusData2018-2023\2023\202302868
#
# ===== Processing file 2870/2890: d:\projectData\ScopusData2018-2023\2023\202302869
#
# ===== Processing file 2871/2890: d:\projectData\ScopusData2018-2023\2023\202302870
#
# ===== Processing file 2872/2890: d:\projectData\ScopusData2018-2023\2023\202302871
#
# ===== Processing file 2873/2890: d:\projectData\ScopusData2018-2023\2023\202302872
#
# ===== Processing file 2874/2890: d:\projectData\ScopusData2018-2023\2023\202302873
#
# ===== Processing file 2875/2890: d:\projectData\ScopusData2018-2023\2023\202302874
#
# ===== Processing file 2876/2890: d:\projectData\ScopusData2018-2023\2023\202302875
#
# ===== Processing file 2877/2890: d:\projectData\ScopusData2018-2023\2023\202302876
#
# ===== Processing file 2878/2890: d:\projectData\ScopusData2018-2023\2023\202302877
#
# ===== Processing file 2879/2890: d:\projectData\ScopusData2018-2023\2023\202302878
#
# ===== Processing file 2880/2890: d:\projectData\ScopusData2018-2023\2023\202302879
#
# ===== Processing file 2881/2890: d:\projectData\ScopusData2018-2023\2023\202302880
#
# ===== Processing file 2882/2890: d:\projectData\ScopusData2018-2023\2023\202302881
#
# ===== Processing file 2883/2890: d:\projectData\ScopusData2018-2023\2023\202302882
#
# ===== Processing file 2884/2890: d:\projectData\ScopusData2018-2023\2023\202302883
#
# ===== Processing file 2885/2890: d:\projectData\ScopusData2018-2023\2023\202302884
#
# ===== Processing file 2886/2890: d:\projectData\ScopusData2018-2023\2023\202302885
#
# ===== Processing file 2887/2890: d:\projectData\ScopusData2018-2023\2023\202302886
#
# ===== Processing file 2888/2890: d:\projectData\ScopusData2018-2023\2023\202302887
#
# ===== Processing file 2889/2890: d:\projectData\ScopusData2018-2023\2023\202302888
#
# ===== Processing file 2890/2890: d:\projectData\ScopusData2018-2023\2023\202302889
#
# =====================================
# Finished processing 2890 valid files out of 2890

# %%
all_results = []

for file_path in json_files:
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    dataframes = extract_all_to_dataframes(data)
    if not dataframes:
        continue

    # Build a NEW output dictionary each iteration
    output = {
        "title": dataframes['core_metadata']["title"].iloc[0],
        "abstract": dataframes['other_info']["abstracts"].iloc[0],
        "author_keywords": dataframes['other_info']["author_keywords"].nunique(),
        "author_counted": int(dataframes['authors']["sequence"].nunique()),
        "subject_area": dataframes["subject_areas"]["subject_area"].tolist(),
        "subject_code": dataframes["subject_areas"]["subject_code"].tolist(),
        "classification_type": dataframes["classifications"]["classification_type"].tolist(),
        "classification_code": dataframes["classifications"]["classification_code"].tolist(),
        "cited_by_count": dataframes["core_metadata"]["cited_by_count"].iloc[0],
        "description": dataframes["core_metadata"]["description"].iloc[0],
        "document_type": dataframes["core_metadata"]["document_type"].iloc[0],
        "publication_year": dataframes['source_info']["publication_year"].iloc[0],
        "publisher": dataframes['source_info']['publisher_name'].iloc[0],
        "issn": dataframes['source_info']["issn_print"].iloc[0],
        "affiliation_countries": dataframes['affiliations']['country'].unique().tolist(),
        "institution_name": dataframes['affiliations']['name'].tolist(),
        "citation_code": dataframes['citation_info']['citation_type'].iloc[0],
        "dc_identifier": dataframes['other_info']["dc:identifier"].iloc[0],
        "prism_publicationName" :dataframes['other_info']["prism:publicationName"].iloc[0],
        "references": []
    }

    ref_df = dataframes['references']
    for _, row in ref_df.iterrows():
        output["references"].append({
            "ref_fulltext": row["ref_fulltext"],
            "author_surnames": row["author_surnames"],
            "author_initials": row["author_initials"],
            "author_count": int(row["author_count"]),
            "title": row["title"],
            "publication_year": row["publication_year"],
            "volume": row["volume"],
            "first_page": row["first_page"],
            "last_page": row["last_page"],
            "page_range": row["page_range"],
            "source_title": row["source_title"],
            "item_id_types": row["item_id_types"],
            "item_id_values": row["item_id_values"]
        })

    # Append a NEW copy each time
    all_results.append(output)

# %%
import json

with open("year2019.json", "w", encoding="utf-8") as f:
    json.dump(all_results, f, indent=4, ensure_ascii=False)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
